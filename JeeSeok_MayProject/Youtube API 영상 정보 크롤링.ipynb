# %% [markdown]
# # 리그오브 레전드 유튜버
# ### 구독자 많은 순서
#
# 뜨뜨뜨뜨 - 재생목록으로 접근
# T1 Faker - 모든 영상으로 접근  (UCpJw2H9KKqwCCGQKRh1Bf2w)
# 괴물쥐 유튜브 - 재생목록으로 접근
# 테스터훈 TesterHoon - 재생목록으로 접근(장인 초대석)
# 랄로 - 재생목록으로 접근

# %% [markdown]
# ### 조회수 높은 순서
#
# 울프
# 파카
# 김민교
# 백크

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import re
import os
import requests
import unicodedata
import pprint
import pandas as pd
import numpy as np

# %% [markdown]
# AIzaSyDzgKhTQY61jMTR612XV-m-n4E_Tc_nxGg
# AIzaSyBOOwTA0_K-6nwi9RFjf42oe07X6Gru0vQ

# %%
os.chdir('C:/Users/USER/Desktop/데브코스/JeeSeok_MayProject/csv 파일')

DEVELOPER_KEY = 'AIzaSyAbQX4MlwUsPUQCy40TLDSMLVJPTiwfrlk'    # 유튜브 API 키
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey = DEVELOPER_KEY)

# %%
game_channel_Id = {'우주하마' : 'UC2NFRq9s2neD_Ml0tPhNC2Q',
                   'T1 Faker' : 'UCpJw2H9KKqwCCGQKRh1Bf2w',
                   '괴물쥐 유튜브' : 'UCDBAVzfX3yZ1hah0FHnOoaA',
                   '테스터훈 TesterHoon' : 'UCUbOogiD-4PKDqaJfSOTC0g',
                   '랄로' : 'UCD2YO_A_PVMgMDN9jpRrpVA',
                   'Wolf' : 'UCYJ0Ucu9jPX5kn6SeDcNaIQ',
                   'PAKA' : 'UCJpAwvQaZyCI5spAz7tipGA',
                   '이상호' : 'UCfIUuMA7U_jImP7oWfTe4Pw',
                   '도티 TV' : 'UChQ-VMvdGrYZxviQVMTJOHg',
                   '악동 김블루' :'UCNzcxCN_Hh_lu5RCSFXKgGQ' }

# %%
animal_channel_Id =  {'SBS TV동물농장x애니멀봐': 'UC22go5LdQEw-iDuxFb4C0hw',
                        '크림히어로즈': 'UCmLiSrat4HW2k07ahKEJo4w',
                        '수리노을SuriNoel': 'UCLsj_Re3SxtkbZfX_ypY1eQ',
                        '22똥괭이네': 'UCYaBl0gtXV_3sHW4bQjq0hA',
                        '매탈남': 'UC29-IlHm6kbDB1ox8GthODw',
                        '밀키복이탄이MilkyBokiTan': 'UCP1CQH2PVJv4-glNTuVJl3g',
                        '슈앤트리 SHU AND TREE': 'UCij19II32Olbu8_vghmYNCA',
                        '정브르': 'UCOv1v2iptqYMVEwLAIUOhPw',
                        '다흑': 'UCwl9OALh8IMwSv_kFdHlMDA',
                        'haha ha': 'UCOp66Vup07X0YziXaaxqs2A'}

# %%
movie_channel_Id =  {'지무비 : G Movie': 'UCaHGOzOyeYzLQeKsVkfLEGA',
                    '고몽': 'UCpcft4FJXgUjnxWoQYsl7Ug',
                    '김시선': 'UC79hJz6y1EEiIkwfHOuWC4w',
                    "리뷰엉이: Owl's Review": 'UCrBpV_pG2kyMMEHCMTNzjAQ',
                    '달빛뮤즈': 'UCMguxwveCsLVpyKrLz-EFTg',
                    '뭅뭅': 'UCJOTgAmY3S0mz-6imyhkj8g',
                    'B Man 삐맨': 'UCxlv4aOnrRTXMRSL8bVJqEw',
                    '드림텔러(DreamTeller)': 'UCpCiIDf9UrfRqte55FHWlYQ'}

# %%
sports_channel_Id = {'피지컬갤러리': 'UCdtRAcd3L_UpV4tMXCw63NQ',
                    '김종국': 'UCoe-0EVDJnjlSoPK8ygcGwQ',
                    'SPOTV': 'UCtm_QoN2SIxwCE-59shX7Qg',
                    '힙으뜸': 'UC4yq3FWEWqMvFNFBsV3gbKQ',
                    '슛포러브': 'UCdTDdygpZKdDew2s1s419iw',
                    '김연경': 'UCVhUw50KohEPkjL3Ox2saag',
                    '말왕': 'UCYJDUekoQz0-bo8al1diLWQ',
                    'JK아트사커': 'UCT8DsZlac7D1_dx6d8Kh_Qw'}

# %%
mukbang_channel_Id = {'제인': 'UC2fsxQr6Hcx1enORxXgKpxQ',
                    '홍유': 'UCxtLc0Jqq3SKBWlIXM_OC9g',
                    '햄지': 'UCPKNKldggioffXPkSmjs5lQ',
                    '쏘영': 'UC4PpFUrfT2Pou7OwpVF0MUQ',
                    '문복희': 'UCoLQZ4ZClFqVPCvvjuiUSRA',
                    '쯔양': 'UCfpaSruWW3S4dibonKXENjA',
                    '푸메': 'UCbzI92w5vWa6mEj1dACfy6g',
                    '떵개떵': 'UC-i2ywiuvjvpTy2zW-tXfkw'}

# %%
def extract_channelId(channel_name):
    #타입을 채널로 설정하여 채널 이름으로 검색했을 때 첫번째 나오는 채널의 ID를 갖고온다.
    
    search_response = youtube.search().list(
        q = channel_name,
        order = "relevance", # 관련성 순
        type = 'channel',
        part = "snippet",
        maxResults = 2,
        ).execute()

    return search_response['items'][0]['id']['channelId']

# %%
def extract_channel_info(channel_id):
    # 채널 id로 접근하여 채널의 총 조회수, 구독자수, 영상 개수를 갖고온다.
    
    channel_response = youtube.channels().list(
        part="statistics",
        id=channel_id
    ).execute()

    total_viewCount = channel_response['items'][0]['statistics']['viewCount']
    subscriberCount = channel_response['items'][0]['statistics']['subscriberCount']
    videoCount = channel_response['items'][0]['statistics']['videoCount']
    return [total_viewCount, subscriberCount, videoCount]

# %%
# 모든 채널의 총 조회수, 구독자수, 영상 개수를 저장
for key, value in game_channel.items():
    game_channel_info[key] = channel_info(value)

# %%
def extract_video_Id(channel_Id):
    # 채널 Id로 접근하여 채널의 최근 100개 동영상의 ID 추출하기

    video_Ids = []

    videos_response = youtube.search().list(
        part="snippet",
        channelId=channel_Id,
        order="date",
        type="video",
        maxResults=50
    ).execute()
    
    nextPageToken = videos_response['nextPageToken']
    
    for video in videos_response['items']:
        video_Ids.append(video['id']['videoId'])
    
    # 한번에 50개만 나오기 때문에 다음 페이지로 넘어가야 함.
    nextpage_response = youtube.search().list(
        part="snippet",
        channelId=channel_Id,
        order="date",
        type="video",
        pageToken = nextPageToken,
        maxResults=50).execute()
    
    for video in nextpage_response['items']:
        if video['id']['videoId'] in video_Ids:
            continue
        video_Ids.append(video['id']['videoId'])

    return video_Ids

# %%
def extract_video_info(videoId):
    view_video_dicts = {}
    for k in range(len(videoId)):
        if videoId[k] == '#NAME?':
            continue
            
        videoIdslists = youtube.videos().list(
            part='snippet, statistics',
            id=videoId[k],
        ).execute()
        items = videoIdslists['items'][0]
        try :
            likeCount = items['statistics']['likeCount']
        except KeyError as e:
            likeCount = "표시되지 않음"
            
        try :
            commentCount = items['statistics']['commentCount']
        except KeyError as e:
            commentCount = "표시되지 않음"
            
        try :
            tags = items['snippet']['tags']
        except KeyError as e:
            tags = ""

        view_video_dicts[videoId[k]] = [items['snippet']['channelId'], 
                                        items['snippet']['title'], items['snippet']['publishedAt'], 
                                        items['statistics']['viewCount'], likeCount,
                                        commentCount, tags, items['snippet']['thumbnails']['high']['url'], 
                                       f'https://www.youtube.com/watch?v={videoId[k]}']
        video_df = pd.DataFrame.from_dict(data=view_video_dicts, orient='index',
                                          columns=['채널Id','영상제목','업로드날짜','조회수','좋아요','댓글','해시태그','썸네일','Url'])
    return video_df

# %%
extract_video_info(list(game['영상Id'])).to_csv('GAME_CHANNEL_VIDEO_INFO.csv',mode = 'a', encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-946509b44215> in <module>
# ----> 1 extract_video_info(list(game['영상Id'])).to_csv('GAME_CHANNEL_VIDEO_INFO.csv',mode = 'a', encoding="utf-8-sig")
#
# <ipython-input-26-67e1ce20b3e3> in extract_video_info(videoId)
#       5             continue
#       6
# ----> 7         videoIdslists = youtube.videos().list(
#       8             part='snippet, statistics',
#       9             id=videoId[k],
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     129                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130                     logger.warning(message)
# --> 131             return wrapped(*args, **kwargs)
#     132
#     133         return positional_wrapper
#
# ~\anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     920
#     921         # Handle retries for server-side errors.
# --> 922         resp, content = _retry_request(
#     923             http,
#     924             num_retries,
#
# ~\anaconda3\lib\site-packages\googleapiclient\http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     188         try:
#     189             exception = None
# --> 190             resp, content = http.request(uri, method, *args, **kwargs)
#     191         # Retry on SSL errors and socket timeout errors.
#     192         except _ssl_SSLError as ssl_error:
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1699                     content = b""
#    1700                 else:
# -> 1701                     (response, content) = self._request(
#    1702                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703                     )
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1419             auth.request(method, request_uri, headers, body)
#    1420
# -> 1421         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1422
#    1423         if auth:
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1371                 pass
#    1372             try:
# -> 1373                 response = conn.getresponse()
#    1374             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1375                 # If we get a BadStatusLine on the first try then that means
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mukbang = pd.read_csv('C:/Users/USER/Desktop/데브코스/JeeSeok_MayProject/csv 파일/MUKBANG_CHANNEL_VIDEO_INFO.csv')

# %%
https://i.ytimg.com/vi/S1irD7QWvkw/hqdefault.jpg
https://www.youtube.com/watch?v=S1irD7QWvkw

# %%
mukbang
# Out:
#             영상Id                      채널Id  \
# 0    KyHGzyaIFTc  UC2fsxQr6Hcx1enORxXgKpxQ
# 1    Y8bvgecTqo4  UC2fsxQr6Hcx1enORxXgKpxQ
# 2    1SmyVCmoRD8  UC2fsxQr6Hcx1enORxXgKpxQ
# 3    rmRx0CBU86s  UC2fsxQr6Hcx1enORxXgKpxQ
# 4    DTkT6ToYwgc  UC2fsxQr6Hcx1enORxXgKpxQ
# ..           ...                       ...
# 794  qumz4DAT2M0  UC-i2ywiuvjvpTy2zW-tXfkw
# 795  2KKJVhHu18Q  UC-i2ywiuvjvpTy2zW-tXfkw
# 796  kXeOLyITVS4  UC-i2ywiuvjvpTy2zW-tXfkw
# 797  fnew9mjHvn8  UC-i2ywiuvjvpTy2zW-tXfkw
# 798  HU31ZC5GA4I  UC-i2ywiuvjvpTy2zW-tXfkw
#
#                                                   영상제목                 업로드날짜  \
# 0    ASMR EDIBLE WINDMILL, JELLY GUMMY CANDY 바람개비, ...  2023-05-02T13:39:16Z
# 1                                  jelly 젤리 먹방 #shorts  2023-05-02T10:51:35Z
# 2    ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...  2023-05-01T13:37:07Z
# 3                             watermelon 수박 먹방 #shorts  2023-05-01T11:05:44Z
# 4    ASMR CONVENIENCE STORE *HAMBURGER, FIRE NOODLE...  2023-04-30T13:52:30Z
# ..                                                 ...                   ...
# 794  어니언치킨에 꾸덕한 까르보나라파스타 먹방~!! 리얼사운드 ASMR Mukbang(E...  2023-01-21T12:00:32Z
# 795  제철 딸기가 가득 들어간 딸기화채 먹방~!! 리얼사운드 ASMR Mukbang(Ea...  2023-01-20T12:00:01Z
# 796  버거킹 빅사이즈 스태커3 와퍼 5개 먹방~~!! 리얼사운드  ASMR Mukbang...  2023-01-19T12:00:28Z
# 797  최고의 궁합! 순두부틈새라면과 삼각김밥, 소세지 먹방~!! 리얼사운드 ASMR Mu...  2023-01-18T12:00:41Z
# 798  추억의 옛날즉석떡볶이에 쫄면사리추가! 그리고 꼬마김밥 먹방~!! 리얼사운드  ASM...  2023-01-17T13:00:10Z
#
#         조회수   좋아요   댓글                                               해시태그  \
# 0     17234   890   95  ['mukbang', 'asmr', '먹방', 'JANE', '제인', 'rainb...
# 1     23685   809    0  ['asmr', 'eating', 'asmr eating', 'mukbang', '...
# 2     83582  1904  144  ['asmr', 'eating sounds', 'mukbang', 'no talki...
# 3     53516  1519   11  ['asmr', 'eating', 'asmr eating', 'mukbang', '...
# 4    104316  3256  203  ['mukbang', 'asmr', '먹방', 'JANE', '제인', '편의점',...
# ..      ...   ...  ...                                                ...
# 794  202036  4024  187  ['떵개떵', '떵개', '개떵', '떵개 먹방', '먹방', '먹방 유튜버', '...
# 795  181729  3355  131  ['떵개떵', '떵개', '개떵', '떵개 먹방', '먹방', '먹방 유튜버', '...
# 796  246073  4733  202  ['떵개떵', '떵개', '개떵', '떵개 먹방', '먹방', '먹방 유튜버', '...
# 797  242060  4797  162  ['떵개떵', '떵개', '개떵', '떵개 먹방', '먹방', '먹방 유튜버', '...
# 798  213588  4410  161  ['떵개떵', '떵개', '개떵', '떵개 먹방', '먹방', '먹방 유튜버', '...
#
#                                                   썸네일  \
# 0    https://i.ytimg.com/vi/KyHGzyaIFTc/hqdefault.jpg
# 1    https://i.ytimg.com/vi/Y8bvgecTqo4/hqdefault.jpg
# 2    https://i.ytimg.com/vi/1SmyVCmoRD8/hqdefault.jpg
# 3    https://i.ytimg.com/vi/rmRx0CBU86s/hqdefault.jpg
# 4    https://i.ytimg.com/vi/DTkT6ToYwgc/hqdefault.jpg
# ..                                                ...
# 794  https://i.ytimg.com/vi/qumz4DAT2M0/hqdefault.jpg
# 795  https://i.ytimg.com/vi/2KKJVhHu18Q/hqdefault.jpg
# 796  https://i.ytimg.com/vi/kXeOLyITVS4/hqdefault.jpg
# 797  https://i.ytimg.com/vi/fnew9mjHvn8/hqdefault.jpg
# 798  https://i.ytimg.com/vi/HU31ZC5GA4I/hqdefault.jpg
#
#                                              Url
# 0    https://www.youtube.com/watch?v=KyHGzyaIFTc
# 1    https://www.youtube.com/watch?v=Y8bvgecTqo4
# 2    https://www.youtube.com/watch?v=1SmyVCmoRD8
# 3    https://www.youtube.com/watch?v=rmRx0CBU86s
# 4    https://www.youtube.com/watch?v=DTkT6ToYwgc
# ..                                           ...
# 794  https://www.youtube.com/watch?v=qumz4DAT2M0
# 795  https://www.youtube.com/watch?v=2KKJVhHu18Q
# 796  https://www.youtube.com/watch?v=kXeOLyITVS4
# 797  https://www.youtube.com/watch?v=fnew9mjHvn8
# 798  https://www.youtube.com/watch?v=HU31ZC5GA4I
#
# [799 rows x 10 columns]

# %%
animal = pd.read_csv('C:/Users/USER/Desktop/데브코스/JeeSeok_MayProject/csv 파일/SPORTS_CHANNEL_VIDEO_INFO.csv')
animal = animal[animal.영상Id != '#NAME?']
thumbnail = [] #리스트 생성
url = []
for video in animal['영상Id'] : #'average' 값을 얻어옴
    if video =='#NAME?':
        continue
    thumbnail.append(f'https://i.ytimg.com/vi/{video}/hqdefault.jpg')
    url.append(f'https://www.youtube.com/watch?v={video}')
animal['썸네일'] = thumbnail #grade열에 순차대로 원소를 대입
animal['Url'] = url
animal.to_csv('SPORTS_CHANNEL_VIDEO_INFO.csv', encoding="utf-8-sig")

# %%
len(mukbang)
# Out:
# 786
