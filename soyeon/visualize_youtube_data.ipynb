# %% [markdown]
# # 먹방 유튜버 8인의 구독자, 동영상, 조회수, 구독자 대비 조회율 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

# %%
plt.rcParams['font.family'] = 'AppleGothic'

# %%
channel_data = pd.read_csv('먹방_유튜버_8인_채널_정보.csv')

channel_data
# Out:
#    Unnamed: 0   이름                      채널id      구독자수  동영상개수     동영상총조회수
# 0           0   제인  UC2fsxQr6Hcx1enORxXgKpxQ  17600000   2093  7232558937
# 1           1   홍유  UCxtLc0Jqq3SKBWlIXM_OC9g  14900000    627  4963417174
# 2           2   햄지  UCPKNKldggioffXPkSmjs5lQ  11200000    592  3785972844
# 3           3   쏘영  UC4PpFUrfT2Pou7OwpVF0MUQ   9750000    787  1482284147
# 4           4  문복희  UCoLQZ4ZClFqVPCvvjuiUSRA   8880000    702  2443206297
# 5           5   쯔양  UCfpaSruWW3S4dibonKXENjA   8080000    518  1848840611
# 6           6   푸메  UCbzI92w5vWa6mEj1dACfy6g   5350000    664  1192313822
# 7           7  떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw   4890000   4916  2985689461

# %%
youtubers = channel_data['이름'].values.tolist()
subscribers = list(map(int, channel_data['구독자수'].values.tolist()))
video_count = list(map(int, channel_data['동영상개수'].values.tolist()))
view_count = list(map(int, channel_data['동영상총조회수'].values.tolist()))

# %%
views_per_subscribers = [int(s) / int(v) for s, v in zip(subscribers, view_count)]

views_per_subscribers
# Out:
# [0.0024334402461572363,
#  0.003001964065815597,
#  0.002958288519620454,
#  0.006577686214706579,
#  0.003634568235561485,
#  0.004370306424429791,
#  0.004487073706002881,
#  0.0016378126606516497]

# %%
fig, ax = plt.subplots(2, 2, figsize=(30, 20))

# 유튜버별 색상 리스트 설정
colors = ['orangered', 'orange', 'yellow', 'greenyellow', 'palegreen',
          'turquoise', 'lightskyblue', 'blueviolet']

# 구독자 수 그래프
ax[0, 0].bar(youtubers, subscribers, color=colors)
ax[0, 0].set_title('Subscribers')

# 동영상 개수 그래프
ax[0, 1].bar(youtubers, video_count, color=colors)
ax[0, 1].set_title('Video Count')

# 동영상 총 조회수 그래프
ax[1, 0].bar(youtubers, view_count, color=colors)
ax[1, 0].set_title('View Count')


# 각 유튜브 별 구독자 수 대비 = 동영상 총 조회수 / 구독자 수
ax[1, 1].bar(youtubers, views_per_subscribers, color=colors)
ax[1, 1].set_title('Views per Subscribers')
# Out:
# Text(0.5, 1.0, 'Views per Subscribers')

# %% [markdown]
# - 보충할 사항 : 범례 범위
#
# 떵개떵의 유튜브 데뷔일은 2014년이라고 나와있는데, 그래서 비디오 업로드 개수가 제일 많은건가?
# 쏘양의 viewCount가 적은데도 불구하고 구독자 대비 조회율은 높다

# %% [markdown]
# # 먹방 유튜브 8인의 최근 동영상 데이터 100개의 그래프 그려보기

# %%
video_data = pd.read_csv('먹방_유튜버_8인_최근동영상100개_상세정보.csv', encoding='utf-8', index_col=0)

# %%
video_data
# Out:
#                이름                      채널ID        동영상ID  \
# 0    Jane ASMR 제인  UC2fsxQr6Hcx1enORxXgKpxQ  1SmyVCmoRD8
# 1    Jane ASMR 제인  UC2fsxQr6Hcx1enORxXgKpxQ  rmRx0CBU86s
# 2    Jane ASMR 제인  UC2fsxQr6Hcx1enORxXgKpxQ  DTkT6ToYwgc
# 3    Jane ASMR 제인  UC2fsxQr6Hcx1enORxXgKpxQ  vGwKEwyfJv4
# 4    Jane ASMR 제인  UC2fsxQr6Hcx1enORxXgKpxQ  _QkYkC11IN0
# ..            ...                       ...          ...
# 795           떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw  2KKJVhHu18Q
# 796           떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw  kXeOLyITVS4
# 797           떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw  fnew9mjHvn8
# 798           떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw  HU31ZC5GA4I
# 799           떵개떵  UC-i2ywiuvjvpTy2zW-tXfkw  LAfV1r8jwvI
#
#                                                     제목     조회수  좋아요수  댓글수
# 0    ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...   56008  1602  144
# 1                             watermelon 수박 먹방 #shorts   42768  1315   10
# ...

# %%
video_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 0 to 799
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      800 non-null    object
#  1   채널ID    800 non-null    object
#  2   동영상ID   800 non-null    object
#  3   제목      800 non-null    object
#  4   조회수     800 non-null    int64
#  5   좋아요수    800 non-null    int64
#  6   댓글수     800 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 50.0+ KB

# %%
# 최근 동영상 데이터 100개의 총 조회수
total_recent_view_count = video_data.groupby("이름")['조회수'].sum()
total_recent_view_count_df = total_recent_view_count.to_frame()
# Out:
#                          조회수
# 이름
# Hongyu ASMR 홍유     219527047
# Jane ASMR 제인        19265357
# [햄지]Hamzy          159026482
# tzuyang쯔양          265052774
# 떵개떵                 19408441
# 문복희 Eat with Boki  179820393
# 쏘영 Ssoyoung         75872505
# 푸메Fume              62498077

# %%
name_list = total_recent_view_count_df.index.tolist()
name_list
# Out:
# ['Hongyu ASMR 홍유',
#  'Jane ASMR 제인',
#  '[햄지]Hamzy',
#  'tzuyang쯔양',
#  '떵개떵',
#  '문복희 Eat with Boki',
#  '쏘영 Ssoyoung',
#  '푸메Fume']

# %%
value_list = [value[0] for value in total_recent_view_count_df.values.tolist()]
value_list
# Out:
# [219527047,
#  19265357,
#  159026482,
#  265052774,
#  19408441,
#  179820393,
#  75872505,
#  62498077]

# %%
# 유튜버별 색상 리스트 설정
colors = ['orangered', 'orange', 'yellow', 'greenyellow', 'palegreen',
          'turquoise', 'lightskyblue', 'blueviolet']

# 막대 그래프 시각화
plt.figure(figsize=(30, 20))
plt.rc('font', size=20)

plt.barh(name_list, value_list, color=colors)
plt.xlabel('유튜버')
plt.ylabel('조회수')
plt.title('최근 동영상 100개의 총 조회수')
plt.show()

# %% [markdown]
# - 구독자 대비 조회율 확인하기

# %%
# 데이터프레임 새로 만들기
name = channel_data['이름'].values.tolist()
subscribers = channel_data['구독자수'].values.tolist()
recent_view_list = [value[0] for value in total_recent_view_count_df.values.tolist()]
# Out:
# [17600000, 14900000, 11200000, 9750000, 8880000, 8080000, 5350000, 4890000]

# %% [markdown]
# ## 5/3 시각화

# %%
channel_data = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

channel_data
# Out:
#    category                channel_id          channel_name  \
# 0    ANIMAL  UC22go5LdQEw-iDuxFb4C0hw       SBS TV동물농장x애니멀봐
# 1    ANIMAL  UCmLiSrat4HW2k07ahKEJo4w                크림히어로즈
# 2    ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ          수리노을SuriNoel
# 3    ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA                22똥괭이네
# 4    ANIMAL  UC29-IlHm6kbDB1ox8GthODw                   매탈남
# 5    ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g    밀키복이탄이MilkyBokiTan
# 6    ANIMAL  UCij19II32Olbu8_vghmYNCA     슈앤트리 SHU AND TREE
# 7    ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                   정브르
# 8    ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                    다흑
# 9    ANIMAL  UCOp66Vup07X0YziXaaxqs2A               haha ha
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA         지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                    고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                   김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ    리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                  달빛뮤즈
# ...

# %% [markdown]
# ### 카테고리별로 조회수와 구독자수 합계 비교

# %%
channel_data
# Out:
#    category                channel_id          channel_name  \
# 0    ANIMAL  UC22go5LdQEw-iDuxFb4C0hw       SBS TV동물농장x애니멀봐
# 1    ANIMAL  UCmLiSrat4HW2k07ahKEJo4w                크림히어로즈
# 2    ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ          수리노을SuriNoel
# 3    ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA                22똥괭이네
# 4    ANIMAL  UC29-IlHm6kbDB1ox8GthODw                   매탈남
# 5    ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g    밀키복이탄이MilkyBokiTan
# 6    ANIMAL  UCij19II32Olbu8_vghmYNCA     슈앤트리 SHU AND TREE
# 7    ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                   정브르
# 8    ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                    다흑
# 9    ANIMAL  UCOp66Vup07X0YziXaaxqs2A               haha ha
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA         지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                    고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                   김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ    리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                  달빛뮤즈
# ...

# %% [markdown]
# - 구독자 수는 만, 조회수는 백만으로 나눔

# %%
channel_tmp_data = channel_data.copy()
channel_tmp_data['subscribers_count'] = channel_tmp_data['subscribers_count'] / 10000
channel_tmp_data['total_views'] = channel_tmp_data['total_views'] / 1000000

# %%
channel_tmp_data
# Out:
#    category                channel_id          channel_name  \
# 0    ANIMAL  UC22go5LdQEw-iDuxFb4C0hw       SBS TV동물농장x애니멀봐
# 1    ANIMAL  UCmLiSrat4HW2k07ahKEJo4w                크림히어로즈
# 2    ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ          수리노을SuriNoel
# 3    ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA                22똥괭이네
# 4    ANIMAL  UC29-IlHm6kbDB1ox8GthODw                   매탈남
# 5    ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g    밀키복이탄이MilkyBokiTan
# 6    ANIMAL  UCij19II32Olbu8_vghmYNCA     슈앤트리 SHU AND TREE
# 7    ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                   정브르
# 8    ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                    다흑
# 9    ANIMAL  UCOp66Vup07X0YziXaaxqs2A               haha ha
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA         지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                    고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                   김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ    리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                  달빛뮤즈
# ...

# %%
category_grouped = channel_tmp_data.groupby('category').mean()   # 평균

subscribers = category_grouped['subscribers_count'].values.tolist()
videos = category_grouped['videos_count'].values.tolist()
views = category_grouped['total_views'].values.tolist()

# %%
categories = category_grouped.index.tolist()
categories
# Out:
# ['ANIMAL', 'FILM', 'GAMING', 'MUKBANG', 'SPORT']

# %%
category_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, ANIMAL to SPORT
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscribers_count  5 non-null      float64
#  1   videos_count       5 non-null      float64
#  2   total_views        5 non-null      float64
# dtypes: float64(3)
# memory usage: 332.0+ bytes

# %%
print(categories)
print(subscribers)
print(videos)
print(views)
# Out:
# ['ANIMAL', 'FILM', 'GAMING', 'MUKBANG', 'SPORT']
# [186.45, 160.875, 124.42, 1008.25, 173.4375]
# [1524.0, 869.875, 1654.9, 1363.25, 2088.875]
# [1036.9705527, 649.845619875, 922.198435, 3243.4175205, 623.643923125]

# %%
grouped_df = channel_tmp_data.groupby('category').mean().reset_index()
grouped_df
# Out:
#   category  subscribers_count  videos_count  total_views
# 0   ANIMAL           186.4500      1524.000  1036.970553
# 1     FILM           160.8750       869.875   649.845620
# 2   GAMING           124.4200      1654.900   922.198435
# 3  MUKBANG          1008.2500      1363.250  3243.417521
# 4    SPORT           173.4375      2088.875   623.643923

# %%
grouped_df.shape[0]
# Out:
# 5

# %%
grouped_df.columns
# Out:
# Index(['category', 'subscribers_count', 'videos_count', 'total_views'], dtype='object')

# %%
import numpy as np

w = 0.15
nrow = grouped_df.shape[0] # 행의 갯수
idx = np.arange(nrow)

plt.figure(figsize = (10, 5))
plt.bar(idx - 2 * w, grouped_df['subscribers_count'], width = w, label='Subscibers')
plt.bar(idx - w, grouped_df['videos_count'], width = w, label='Videos')
plt.bar(idx, grouped_df['total_views'], width = w, label='Total Views')
plt.xticks(idx, grouped_df['category'], rotation = 30)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['ANIMAL', 'FILM', 'GAMING', 'MUKBANG', 'SPORT']
y1 = [186.45, 160.875, 124.42, 1008.25, 173.4375]
y2 =[1524.0, 869.875, 1654.9, 1363.25, 2088.875]
y3 =[1036.9705527, 649.845619875, 922.198435, 3243.4175205, 623.643923125]

# 첫번째 y 데이터에 대한 바차트
fig, ax1 = plt.subplots()
ax1.bar(x, y1, label='y1', color='C0')
ax1.set_ylabel('y1')

# 두번째 y 데이터에 대한 바차트
ax2 = ax1.twinx()
ax2.bar(x, y2, label='y2', color='C1')
ax2.set_ylabel('y2')

# 세번째 y 데이터에 대한 바차트
ax3 = ax1.twinx()
ax3.spines.right.set_position(('axes', 1.2)) # y축 위치 조정
ax3.bar(x, y3, label='y3', color='C2', alpha=0.5)
ax3.set_ylabel('y3')

# 범례 추가
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax3.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc='upper left')

plt.show()

# %%
# mukbang_df랑 channel_df 조인하기
mukbang_df = pd.read_csv('./../src/MUKBANG_CHANNEL_VIDEO_INFO.csv', encoding='utf-8', index_col=0)
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

# %%
mukbang_df.columns
# Out:
# Index(['채널Id', '영상제목', '업로드날짜', '조회수', '좋아요', '댓글', '해시태그'], dtype='object')

# %% [markdown]
# ## 유튜버별 업로드날짜에 대한 조회수 확인

# %%
mukbang_df['업로드날짜'] = pd.to_datetime(mukbang_df['업로드날짜'])

# %%
mukbang_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 799 entries, KyHGzyaIFTc to HU31ZC5GA4I
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   채널Id    799 non-null    object
#  1   영상제목    799 non-null    object
#  2   업로드날짜   799 non-null    datetime64[ns, UTC]
#  3   조회수     799 non-null    int64
#  4   좋아요     799 non-null    int64
#  5   댓글      799 non-null    int64
#  6   해시태그    798 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(3), object(3)
# memory usage: 49.9+ KB

# %%
# 데이터프레임 조인하기
merged_df = pd.merge(mukbang_df, channel_df, left_on='채널Id', right_on='channel_id', how='left')

# %%
merged_df
# Out:
#                          채널Id  \
# 0    UC2fsxQr6Hcx1enORxXgKpxQ
# 1    UC2fsxQr6Hcx1enORxXgKpxQ
# 2    UC2fsxQr6Hcx1enORxXgKpxQ
# 3    UC2fsxQr6Hcx1enORxXgKpxQ
# 4    UC2fsxQr6Hcx1enORxXgKpxQ
# ..                        ...
# 794  UC-i2ywiuvjvpTy2zW-tXfkw
# 795  UC-i2ywiuvjvpTy2zW-tXfkw
# 796  UC-i2ywiuvjvpTy2zW-tXfkw
# 797  UC-i2ywiuvjvpTy2zW-tXfkw
# 798  UC-i2ywiuvjvpTy2zW-tXfkw
#
#                                                   영상제목  \
# 0    ASMR EDIBLE WINDMILL, JELLY GUMMY CANDY 바람개비, ...
# 1                                  jelly 젤리 먹방 #shorts
# 2    ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...
# 3                             watermelon 수박 먹방 #shorts
# 4    ASMR CONVENIENCE STORE *HAMBURGER, FIRE NOODLE...
# ..                                                 ...
# 794  어니언치킨에 꾸덕한 까르보나라파스타 먹방~!! 리얼사운드 ASMR Mukbang(E...
# 795  제철 딸기가 가득 들어간 딸기화채 먹방~!! 리얼사운드 ASMR Mukbang(Ea...
# 796  버거킹 빅사이즈 스태커3 와퍼 5개 먹방~~!! 리얼사운드  ASMR Mukbang...
# ...

# %%
merged_df
# Out:
#                          채널Id  \
# 0    UC2fsxQr6Hcx1enORxXgKpxQ
# 1    UC2fsxQr6Hcx1enORxXgKpxQ
# 2    UC2fsxQr6Hcx1enORxXgKpxQ
# 3    UC2fsxQr6Hcx1enORxXgKpxQ
# 4    UC2fsxQr6Hcx1enORxXgKpxQ
# ..                        ...
# 794  UC-i2ywiuvjvpTy2zW-tXfkw
# 795  UC-i2ywiuvjvpTy2zW-tXfkw
# 796  UC-i2ywiuvjvpTy2zW-tXfkw
# 797  UC-i2ywiuvjvpTy2zW-tXfkw
# 798  UC-i2ywiuvjvpTy2zW-tXfkw
#
#                                                   영상제목  \
# 0    ASMR EDIBLE WINDMILL, JELLY GUMMY CANDY 바람개비, ...
# 1                                  jelly 젤리 먹방 #shorts
# 2    ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...
# 3                             watermelon 수박 먹방 #shorts
# 4    ASMR CONVENIENCE STORE *HAMBURGER, FIRE NOODLE...
# ..                                                 ...
# 794  어니언치킨에 꾸덕한 까르보나라파스타 먹방~!! 리얼사운드 ASMR Mukbang(E...
# 795  제철 딸기가 가득 들어간 딸기화채 먹방~!! 리얼사운드 ASMR Mukbang(Ea...
# 796  버거킹 빅사이즈 스태커3 와퍼 5개 먹방~~!! 리얼사운드  ASMR Mukbang...
# ...

# %%
grouped_df = merged_df.groupby(['channel_id', pd.Grouper(key='업로드날짜', freq='D')]).sum().reset_index()

# %%
grouped_df
# Out:
#                    channel_id                     업로드날짜     조회수   좋아요   댓글  \
# 0    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-17 00:00:00+00:00  213588  4410  161
# 1    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-18 00:00:00+00:00  242060  4797  162
# 2    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-19 00:00:00+00:00  246073  4733  202
# 3    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-20 00:00:00+00:00  181729  3355  131
# 4    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-21 00:00:00+00:00  202036  4024  187
# ..                        ...                       ...     ...   ...  ...
# 735  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-24 00:00:00+00:00  586069  5208  190
# 736  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-26 00:00:00+00:00  297340  4684  183
# 737  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-28 00:00:00+00:00  408719  4700  164
# 738  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-30 00:00:00+00:00  214437  5715  160
# 739  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-05-02 00:00:00+00:00   51834  1363   82
#
#      subscribers_count  videos_count  total_views
# ...

# %%
# 구독자 수를 날짜별로 그룹화
subscribers = grouped_df.groupby([grouped_df["channel_id"], grouped_df["업로드날짜"].dt.date])["subscribers_count"].mean()

# %%
subscribers
# Out:
# channel_id                업로드날짜
# UC-i2ywiuvjvpTy2zW-tXfkw  2023-01-17     4890000.0
#                           2023-01-18     4890000.0
#                           2023-01-19     4890000.0
#                           2023-01-20     4890000.0
#                           2023-01-21     4890000.0
#                                            ...
# UCxtLc0Jqq3SKBWlIXM_OC9g  2023-04-24    14900000.0
#                           2023-04-26    14900000.0
#                           2023-04-28    14900000.0
#                           2023-04-30    14900000.0
#                           2023-05-02    14900000.0
# Name: subscribers_count, Length: 740, dtype: float64

# %% [markdown]
# - 일별, 주별, 월별 뽑아야 함
#     - 일별로 먼저 확인해보고 문제가 없으면 늘려보자

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 5))
ax2 = ax1.twinx()

ax1.bar(grouped_df['업로드날짜'], grouped_df['subscribers_count'], color='tab:blue')
ax2.plot(grouped_df['업로드날짜'], grouped_df['조회수'], color='tab:red')

ax1.set_xlabel('날짜')
ax1.set_ylabel('구독자 수', color='tab:blue')
ax2.set_ylabel('조회수', color='tab:red')

plt.show()

# %% [markdown]
# - x축은 유튜버
# - 꺾은선 : 총 조회수,

# %% [markdown]
# ## 제인 유튜버의 날짜별 조회수 및 구독자 확인
#
# - x축은 일자
# - 바 그래프 > 조회수 / 1000000 (단위 꼭 명시할것)
# - 선 그래프 >

# %%
grouped_df = merged_df.groupby(['channel_id', pd.Grouper(key='업로드날짜', freq='D')]).sum().reset_index()

grouped_df
# Out:
#                    channel_id                     업로드날짜     조회수   좋아요   댓글  \
# 0    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-17 00:00:00+00:00  213588  4410  161
# 1    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-18 00:00:00+00:00  242060  4797  162
# 2    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-19 00:00:00+00:00  246073  4733  202
# 3    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-20 00:00:00+00:00  181729  3355  131
# 4    UC-i2ywiuvjvpTy2zW-tXfkw 2023-01-21 00:00:00+00:00  202036  4024  187
# ..                        ...                       ...     ...   ...  ...
# 735  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-24 00:00:00+00:00  586069  5208  190
# 736  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-26 00:00:00+00:00  297340  4684  183
# 737  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-28 00:00:00+00:00  408719  4700  164
# 738  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-04-30 00:00:00+00:00  214437  5715  160
# 739  UCxtLc0Jqq3SKBWlIXM_OC9g 2023-05-02 00:00:00+00:00   51834  1363   82
#
#      subscribers_count  videos_count  total_views
# ...

# %%
df = grouped_df[grouped_df['channel_id'] == 'UC2fsxQr6Hcx1enORxXgKpxQ']

df
# Out:
#                    channel_id                     업로드날짜      조회수    좋아요   댓글  \
# 100  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-23 00:00:00+00:00  3073877  39859  305
# 101  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-24 00:00:00+00:00   198213   4406  335
# 102  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-25 00:00:00+00:00  1348277  27097  333
# 103  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-26 00:00:00+00:00   179131   3827  269
# 104  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-27 00:00:00+00:00   501370   4162  250
# 105  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-28 00:00:00+00:00   589140  12615  315
# 106  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-29 00:00:00+00:00   975182  14052  251
# 107  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-30 00:00:00+00:00   112069   3584   27
# 108  UC2fsxQr6Hcx1enORxXgKpxQ 2023-03-31 00:00:00+00:00   397167   7414  210
# 109  UC2fsxQr6Hcx1enORxXgKpxQ 2023-04-01 00:00:00+00:00  1081014  20803  305
# 110  UC2fsxQr6Hcx1enORxXgKpxQ 2023-04-02 00:00:00+00:00   481443  12758  286
# ...

# %%
channel_df
# Out:
#    category                channel_id          channel_name  \
# 0    ANIMAL  UC22go5LdQEw-iDuxFb4C0hw       SBS TV동물농장x애니멀봐
# 1    ANIMAL  UCmLiSrat4HW2k07ahKEJo4w                크림히어로즈
# 2    ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ          수리노을SuriNoel
# 3    ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA                22똥괭이네
# 4    ANIMAL  UC29-IlHm6kbDB1ox8GthODw                   매탈남
# 5    ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g    밀키복이탄이MilkyBokiTan
# 6    ANIMAL  UCij19II32Olbu8_vghmYNCA     슈앤트리 SHU AND TREE
# 7    ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                   정브르
# 8    ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                    다흑
# 9    ANIMAL  UCOp66Vup07X0YziXaaxqs2A               haha ha
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA         지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                    고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                   김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ    리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                  달빛뮤즈
# ...

# %%
# 업로드날짜를 x축으로, 구독자 수와 조회수를 y축으로
fig, ax = plt.subplots()

plt.figure(figsize=(6, 8))

ax.bar(df['업로드날짜'], df['조회수'], color='blue', label='조회수')
ax.bar(df['업로드날짜'], channel_df.loc[channel_df['channel_id'] == 'abc', ' subscribers_count'].values[0], color='orange', label='구독자 수')

# 범례 설정
ax.legend()

# 축 레이블 설정
ax.set_xlabel('업로드날짜')
ax.set_ylabel('조회수/구독자 수')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' subscribers_count'
#
# ...

# %% [markdown]
# ## 재시도

# %%
# mukbang_df랑 channel_df 조인하기
mukbang_df = pd.read_csv('./../src/MUKBANG_CHANNEL_VIDEO_INFO.csv', encoding='utf-8', index_col=0)
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

merged_df = pd.merge(mukbang_df, channel_df, left_on='channel_id', right_on='channel_id', how='left')

merged_df
# Out:
#                    channel_id  \
# 0    UC2fsxQr6Hcx1enORxXgKpxQ
# 1    UC2fsxQr6Hcx1enORxXgKpxQ
# 2    UC2fsxQr6Hcx1enORxXgKpxQ
# 3    UC2fsxQr6Hcx1enORxXgKpxQ
# 4    UC2fsxQr6Hcx1enORxXgKpxQ
# ..                        ...
# 781  UC-i2ywiuvjvpTy2zW-tXfkw
# 782  UC-i2ywiuvjvpTy2zW-tXfkw
# 783  UC-i2ywiuvjvpTy2zW-tXfkw
# 784  UC-i2ywiuvjvpTy2zW-tXfkw
# 785  UC-i2ywiuvjvpTy2zW-tXfkw
#
#                                            video_title  \
# 0    ASMR EDIBLE WINDMILL, JELLY GUMMY CANDY 바람개비, ...
# 1                                  jelly 젤리 먹방 #shorts
# 2    ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...
# 3                             watermelon 수박 먹방 #shorts
# 4    ASMR CONVENIENCE STORE *HAMBURGER, FIRE NOODLE...
# ..                                                 ...
# 781  어니언치킨에 꾸덕한 까르보나라파스타 먹방~!! 리얼사운드 ASMR Mukbang(E...
# 782  제철 딸기가 가득 들어간 딸기화채 먹방~!! 리얼사운드 ASMR Mukbang(Ea...
# 783  버거킹 빅사이즈 스태커3 와퍼 5개 먹방~~!! 리얼사운드  ASMR Mukbang...
# ...

# %%
import re

def preprocess_df(df):

    # T, Z 지우기
    df['uploaded_date'] = [re.sub('[A-Z]'," ",s) for s in df['uploaded_date']]
    # Z 공백 제거
    df['uploaded_date'] = df['uploaded_date'].str.rstrip()

    # 포맷 바꾸기
    df['uploaded_date'] =pd.to_datetime(df['uploaded_date'],
                                      format='%Y-%m-%d', errors='raise')
    df['like_count'] = pd.to_numeric(df['like_count'], errors='coerce').fillna(0).astype(int)

    df['date'] = df['uploaded_date'].dt.date

    # datetime - index설정  (resample사용하기 위해 - 안그러면 에러나옴)
    df = df.set_index('uploaded_date')

    return df

# %%
merged_df = preprocess_df(merged_df)

merged_df
# Out:
#                                    channel_id  \
# uploaded_date
# 2023-05-02 13:39:16  UC2fsxQr6Hcx1enORxXgKpxQ
# 2023-05-02 10:51:35  UC2fsxQr6Hcx1enORxXgKpxQ
# 2023-05-01 13:37:07  UC2fsxQr6Hcx1enORxXgKpxQ
# 2023-05-01 11:05:44  UC2fsxQr6Hcx1enORxXgKpxQ
# 2023-04-30 13:52:30  UC2fsxQr6Hcx1enORxXgKpxQ
# ...                                       ...
# 2023-01-21 12:00:32  UC-i2ywiuvjvpTy2zW-tXfkw
# 2023-01-20 12:00:01  UC-i2ywiuvjvpTy2zW-tXfkw
# 2023-01-19 12:00:28  UC-i2ywiuvjvpTy2zW-tXfkw
# 2023-01-18 12:00:41  UC-i2ywiuvjvpTy2zW-tXfkw
# 2023-01-17 13:00:10  UC-i2ywiuvjvpTy2zW-tXfkw
#
#                                                            video_title  \
# uploaded_date
# 2023-05-02 13:39:16  ASMR EDIBLE WINDMILL, JELLY GUMMY CANDY 바람개비, ...
# 2023-05-02 10:51:35                                jelly 젤리 먹방 #shorts
# 2023-05-01 13:37:07  ASMR RAINBOW FOODS *EDIBLE DICE, CANDY, UNICOR...
# 2023-05-01 11:05:44                           watermelon 수박 먹방 #shorts
# ...

# %%
# 최근 일주일 데이터 추출
one_month_ago = pd.Timestamp.today().normalize() - pd.Timedelta(days=30)
print(one_month_ago)
df_week = merged_df.loc[one_month_ago.strftime('%Y-%m-%d'):]

df_week = df_week[df_week['channel_id'] == 'UCLsj_Re3SxtkbZfX_ypY1eQ']
# Out:
# 2023-04-05 00:00:00
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1349303403.py:4: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_week = merged_df.loc[one_month_ago.strftime('%Y-%m-%d'):]

# %%
df_week
# Out:
#                                    channel_id             video_title  \
# uploaded_date
# 2023-04-11 09:51:00  UCLsj_Re3SxtkbZfX_ypY1eQ  고양이가 원하는 게 있을 때 귀여운 모습
#
#                                                       video_thumbnail  \
# uploaded_date
# 2023-04-11 09:51:00  https://i.ytimg.com/vi/_cW6nsKnsHE/hqdefault.jpg
#
#                                                        video_url  view_count  \
# uploaded_date
# 2023-04-11 09:51:00  https://www.youtube.com/watch?v=_cW6nsKnsHE       41074
#
#                      like_count  comment_count hashtag category  channel_name  \
# uploaded_date
# 2023-04-11 09:51:00        2671            122     NaN   ANIMAL  수리노을SuriNoel
#
#                                                           channel_logo  \
# uploaded_date
# 2023-04-11 09:51:00  https://yt3.ggpht.com/ytc/AGIKgqN9sg6j8ozR0zPo...
#
#                      subscribers_count  videos_count  total_views        date
# uploaded_date
# ...

# %%
df_week['views_per_subscriber'] = df_week['view_count'] / df_week['subscribers_count'] * 100
df_week['likes_per_views'] = (df_week['like_count'] / df_week['view_count']) * 100
df_week['views_10000'] = df_week['view_count'] / 10000

# %%
df_week
# Out:
#                                    channel_id             video_title  \
# uploaded_date
# 2023-04-11 09:51:00  UCLsj_Re3SxtkbZfX_ypY1eQ  고양이가 원하는 게 있을 때 귀여운 모습
#
#                                                       video_thumbnail  \
# uploaded_date
# 2023-04-11 09:51:00  https://i.ytimg.com/vi/_cW6nsKnsHE/hqdefault.jpg
#
#                                                        video_url  view_count  \
# uploaded_date
# 2023-04-11 09:51:00  https://www.youtube.com/watch?v=_cW6nsKnsHE       41074
#
#                      like_count  comment_count hashtag category  channel_name  \
# uploaded_date
# 2023-04-11 09:51:00        2671            122     NaN   ANIMAL  수리노을SuriNoel
#
#                                                           channel_logo  \
# uploaded_date
# 2023-04-11 09:51:00  https://yt3.ggpht.com/ytc/AGIKgqN9sg6j8ozR0zPo...
#
#                      subscribers_count  videos_count  total_views        date  \
# uploaded_date
# ...

# %%
df_week.columns
# Out:
# Index(['channel_id', 'video_title', 'video_thumbnail', 'video_url',
#        'view_count', 'like_count', 'comment_count', 'hashtag', 'category',
#        'channel_name', 'channel_logo', 'subscribers_count', 'videos_count',
#        'total_views', 'date', 'views_per_subscriber', 'likes_per_views',
#        'views_10000'],
#       dtype='object')

# %%
df_week
# Out:
#                                    channel_id             video_title  \
# uploaded_date
# 2023-04-11 09:51:00  UCLsj_Re3SxtkbZfX_ypY1eQ  고양이가 원하는 게 있을 때 귀여운 모습
#
#                                                       video_thumbnail  \
# uploaded_date
# 2023-04-11 09:51:00  https://i.ytimg.com/vi/_cW6nsKnsHE/hqdefault.jpg
#
#                                                        video_url  view_count  \
# uploaded_date
# 2023-04-11 09:51:00  https://www.youtube.com/watch?v=_cW6nsKnsHE       41074
#
#                      like_count  comment_count hashtag category  channel_name  \
# uploaded_date
# 2023-04-11 09:51:00        2671            122     NaN   ANIMAL  수리노을SuriNoel
#
#                                                           channel_logo  \
# uploaded_date
# 2023-04-11 09:51:00  https://yt3.ggpht.com/ytc/AGIKgqN9sg6j8ozR0zPo...
#
#                      subscribers_count  videos_count  total_views        date  \
# uploaded_date
# ...

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

last_30_days = df_week[pd.to_datetime(df_week.index) >= datetime.today() - timedelta(days=30)]

nrow = last_30_days.index.shape[0]
idx = np.arange(nrow)

# 그래프 그리기
fig, ax1 = plt.subplots(figsize=(20, 10))
ax2 = ax1.twinx()

if len(last_30_days) == 1:
    width = 0.4
else:
    width = 15 / len(last_30_days)

# 첫번째 y축: Views, Subscribers, Total Views
ax1.bar(last_30_days.index, last_30_days['views_10000'], color='#aec7e8', label='조회 수(단위: 만)', width=width, align='center')

if len(last_30_days) != 1:
    ax1.bar(last_30_days.index - 2*width, last_30_days['subscribers_count_100000'], width=width, label='구독자 수(단위: 십만)', color='#aec7e8')
    ax1.bar(last_30_days.index - width, last_30_days['total_views_per_videos'] / 10, width=width, label='평균 조회 수(단위: 십만)', color='#FF69B4')
ax1.set_ylabel('조회 수(단위: 만) / 구독자 수(단위: 십만) / 평균 조회 수(단위: 십만)', fontsize=12)

# 두번째 y축: Videos
if len(last_30_days) != 1:
    ax2 = ax1.twinx()
    ax2.bar(last_30_days.index, last_30_days['videos_count'] / last_30_days['videos_count'].sum() * 100, width=width, label='업로드 빈도율(단위: %)', color='#00FF7F')
    ax2.set_ylabel('업로드 빈도율(단위 : %)', fontsize=12)
    ax2.set_ylim([0, 100])

ax1.set_xlabel('날짜')
ax1.tick_params(axis='x', rotation=45)
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%y/%m/%d'))

if len(last_30_days) != 1:
    ax1.set_xlim([last_30_days.index - timedelta(days=0.5), last_30_days.index + timedelta(days=0.5)])
else:
    ax1.set_xlim([last_30_days.index.min() - timedelta(days=1), last_30_days.index.max() + timedelta(days=1)])

ax1.set_ylim([0, df_week['views_10000'].max() * 1.2])
ax1.grid(True, axis='both', which='both')

youtuber_name = channel_df[channel_df['channel_id'] == 'UC-i2ywiuvjvpTy2zW-tXfkw']['channel_name'].values[0]


plt.title(youtuber_name + '의 날짜별 데이터 추이', fontsize=16)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.savefig('./../src/graph/test_graph.png',
            facecolor='#ffffff',
            edgecolor='black',
            format='png', dpi=200)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
channel_id = 'UCOp66Vup07X0YziXaaxqs2A'
category = 'ANIMAL'

# mukbang_df랑 channel_df 조인하기
import matplotlib.dates as mdates
import datetime as dt

df = pd.read_csv('./../src/{}_CHANNEL_VIDEO_INFO.csv'.format(category), encoding='utf-8', index_col=0)
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

merged_df = pd.merge(df, channel_df, left_on='channel_id', right_on='channel_id', how='left')

merged_df = preprocess_df(merged_df)

# 최근 일주일 데이터 추출
one_week_ago = pd.Timestamp.today().normalize() - pd.Timedelta(days=30)
df_week = merged_df.loc[one_week_ago.strftime('%Y-%m-%d'):]
df_week = df_week[df_week['channel_id'] == channel_id]

print(df_week)


df_week['views_per_subscriber'] = df_week['view_count'] / df_week['subscribers_count'] * 100
df_week['likes_per_views'] = (df_week['like_count'] / df_week['view_count']) * 100
df_week['views_10000'] = df_week['view_count'] / 10000

df_week = df_week.groupby('date').mean()

print(df_week)


# 그래프 그리기
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx() # 두번째 y축 생성

ax1.bar(df_week.index, df_week['views_10000'], color='#aec7e8', label='조회 수(단위: 만)', width=0.3)
ax2.plot(df_week.index, df_week['likes_per_views'], color='#FF69B4', label='조회수 대비 좋아요 수 비율(단위: %)', linewidth=2)
ax2.plot(df_week.index, df_week['views_per_subscriber'], color='#00FF7F', alpha=0.5, label='구독자 대비 조회율(단위: %)', linewidth=2)

ax1.set_xlabel('날짜')
ax1.set_ylabel('조회 수(단위: 만)')
ax2.set_ylabel('조회수 대비 좋아요 수 비율(단위: %)/구독자 대비 조회율(단위: %)')

try:
    # 조회수 y축 범위 설정
    ax1.set_ylim([0, df_week['views_10000'].max() * 1.2])

    ax1.tick_params(axis='x', rotation=45)
    # ax1.xaxis.set_major_formatter(mdates.DateFormatter('%y/%m/%d')) # x축 날짜 라벨 형식 설정
    ax1.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax1.xaxis.set_major_formatter(mdates.AutoDateFormatter(mdates.AutoDateLocator()))
    ax1.grid(True, axis='both', which='both')

    # 좋아요 y축 범위 설정
    ax2_max = df_week[['likes_per_views', 'views_per_subscriber']].max().max()
    ax2_min = df_week[['likes_per_views', 'views_per_subscriber']].min().min()
    ax2_range = ax2_max - ax2_min
    ax2.set_ylim([ax2_min - 0.1 * ax2_range, ax2_max + 0.1 * ax2_range])

    # 최근 7일의 날짜 리스트 생성
    date_list = pd.date_range(one_week_ago, periods=7)

    # x축 라벨 설정
    ax1.set_xticks(date_list)
    ax1.set_xticklabels([date.strftime('%Y-%m-%d') for date in date_list])

    # 범례 추가
    youtuber_name = channel_df[channel_df['channel_id'] == channel_id]['channel_name'].values[0]

    plt.title(youtuber_name + '의 날짜별 데이터 추이', fontsize=16)
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')

    plt.tight_layout() # 그래프 레이아웃 조정

    plt.savefig('./../src/graph/{}/{}_VIDEO_GRAPH.png'.format(category, channel_id),
            facecolor='#ffffff',
            edgecolor='black',
            format='png', dpi=200)
    plt.show()

except ValueError:
    pass
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/2613653548.py:16: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_week = merged_df.loc[one_week_ago.strftime('%Y-%m-%d'):]
#                                    channel_id                video_title  \
# uploaded_date
# 2023-04-30 12:58:27  UCOp66Vup07X0YziXaaxqs2A  집고양이에게 최고의 복지라는 캣티오를 만들었다
# 2023-04-26 14:00:44  UCOp66Vup07X0YziXaaxqs2A                   삼색이 브이로그
# 2023-04-22 11:59:42  UCOp66Vup07X0YziXaaxqs2A       무는 얼마나 순둥한지 테스트 해보았다
# 2023-04-19 12:13:48  UCOp66Vup07X0YziXaaxqs2A               궁디팡팡에 중독된 사람
# 2023-04-16 11:10:14  UCOp66Vup07X0YziXaaxqs2A           스스로 장난감을 만드는 고양이
# 2023-04-13 14:02:46  UCOp66Vup07X0YziXaaxqs2A                     새로운 공간
# 2023-04-08 12:43:29  UCOp66Vup07X0YziXaaxqs2A                      만취 야통
#
# ...

# %%
# Out:
# Index(['category', 'channel_id', 'channel_name', 'channel_logo',
#        'subscribers_count', 'videos_count', 'total_views'],
#       dtype='object')

# %%
film_channels_df = channel_df[channel_df['category'] == 'FILM']

film_channels_df
# Out:
#    category                channel_id        channel_name  \
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA       지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                  고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                 김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ  리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                달빛뮤즈
# 15     FILM  UCJOTgAmY3S0mz-6imyhkj8g                  뭅뭅
# 16     FILM  UCxlv4aOnrRTXMRSL8bVJqEw            B Man 삐맨
# 17     FILM  UCpCiIDf9UrfRqte55FHWlYQ   드림텔러(DreamTeller)
#
#                                          channel_logo  subscribers_count  \
# 10  https://yt3.ggpht.com/ytc/AGIKgqMq1Jd-AoSuVFSB...            2870000
# 11  https://yt3.ggpht.com/ytc/AGIKgqOV9UsUupNco-Bq...            2200000
# 12  https://yt3.ggpht.com/ytc/AGIKgqPUJq9j0wa-ab5c...            1580000
# 13  https://yt3.ggpht.com/ytc/AGIKgqNROMFnGpWMOmA2...            1450000
# 14  https://yt3.ggpht.com/_jWWV0MMAXeyUV1OqC8SZ4c6...            1250000
# ...

# %%
film_channels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 10 to 17
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category           8 non-null      object
#  1   channel_id         8 non-null      object
#  2   channel_name       8 non-null      object
#  3   channel_logo       8 non-null      object
#  4   subscribers_count  8 non-null      int64
#  5   videos_count       8 non-null      int64
#  6   total_views        8 non-null      int64
# dtypes: int64(3), object(4)
# memory usage: 512.0+ bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams['font.family'] = 'AppleGothic'

# %%
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

channel_df
# Out:
#    category                channel_id          channel_name  \
# 0    ANIMAL  UC22go5LdQEw-iDuxFb4C0hw       SBS TV동물농장x애니멀봐
# 1    ANIMAL  UCmLiSrat4HW2k07ahKEJo4w                크림히어로즈
# 2    ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ          수리노을SuriNoel
# 3    ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA                22똥괭이네
# 4    ANIMAL  UC29-IlHm6kbDB1ox8GthODw                   매탈남
# 5    ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g    밀키복이탄이MilkyBokiTan
# 6    ANIMAL  UCij19II32Olbu8_vghmYNCA     슈앤트리 SHU AND TREE
# 7    ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                   정브르
# 8    ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                    다흑
# 9    ANIMAL  UCOp66Vup07X0YziXaaxqs2A               haha ha
# 10     FILM  UCaHGOzOyeYzLQeKsVkfLEGA         지무비 : G Movie
# 11     FILM  UCpcft4FJXgUjnxWoQYsl7Ug                    고몽
# 12     FILM  UC79hJz6y1EEiIkwfHOuWC4w                   김시선
# 13     FILM  UCrBpV_pG2kyMMEHCMTNzjAQ    리뷰엉이: Owl's Review
# 14     FILM  UCMguxwveCsLVpyKrLz-EFTg                  달빛뮤즈
# ...

# %% [markdown]
# - 먹방 카테고리 및 구독자의 수가 월등히 높음 > 1000000(쳔만)으로 나눔
# - 단위 통합을 하기 위해 다른 카테고리에도 구독자와 조회수에 각각 천만으로 나누니, 단위가 일치하지 않음...
# - 단위 수만 범례에 잘 정리하고 단위는 카테고리에 따라 알아서 나누는 것으로 할까요?
#
# - 구독자 수... >> 조회수만큼 높아요
# - 총 조회수를 총 영상수로 나눠서 평균 조회수로 보여주는 건 어떤지
#
# - 총 조회수를 영상 수로 나누면 >> 구독자 수랑 비슷한 숫자로 떨어짐 >> 확인 필요!
# - 구독자 수와 평균 조회수 > 막대그래프로 보여주고
# - 유의미한... 정보를

# %%
mukbang_channels_df = channel_df[channel_df['category'] == 'MUKBANG']

# 총 조회수 / 총 비디오 개수
mukbang_channels_df['total_views_per_videos'] = (mukbang_channels_df['total_views'] // mukbang_channels_df['videos_count']) // 100000

# 구독자 수 / 십만
mukbang_channels_df['subscribers_count_100000'] = mukbang_channels_df['subscribers_count'] // 100000

# 조회 수 / 십만
mukbang_channels_df['total_views_100000'] = mukbang_channels_df['total_views'] // 100000

mukbang_channels_df
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1266116455.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mukbang_channels_df['total_views_per_videos'] = (mukbang_channels_df['total_views'] // mukbang_channels_df['videos_count']) // 100000
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1266116455.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mukbang_channels_df['subscribers_count_100000'] = mukbang_channels_df['subscribers_count'] // 100000
# ...

# %%
w = 0.15
nrow = mukbang_channels_df.shape[0] # 행의 갯수
idx = np.arange(nrow)

fig, ax1 = plt.subplots(figsize = (20, 10))

# 첫번째 y축: Subscribers와 Videos
ax1.bar(idx - 2 * w, mukbang_channels_df['subscribers_count_100000'], width = w, label='구독자 수(단위: 십만)', color='blueviolet')
ax1.bar(idx - w, mukbang_channels_df['total_views_per_videos'], width = w, label='평균 조회 수(단위: 십만)', color='lightgreen')
ax1.set_ylabel('구독자 수(단위: 백만) / 평균 조회 수(단위: 십만)', fontsize=12)

# 두번째 y축: Total Views
ax2 = ax1.twinx()
ax2.bar(idx, mukbang_channels_df['videos_count'] / 100, width = w, label='업로드 빈도율(단위: %)', color='lightskyblue')
ax2.set_ylabel('업로드 빈도율(단위 : %)', fontsize=12)

# x축, 타이틀, 범례
plt.xticks(idx, mukbang_channels_df['channel_name'], rotation = 30)
plt.title('먹방 유튜버 순위', fontsize=16)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# y축 범위


ax1_max = max(mukbang_channels_df['subscribers_count_100000'].max(),mukbang_channels_df['total_views_per_videos'].max())

ax1_min = min(mukbang_channels_df['subscribers_count_100000'].min(),mukbang_channels_df['total_views_per_videos'].min())
ax1_range = ax1_max - ax1_min
ax1.set_ylim([0, ax1_max + 0.1 * ax1_range])

ax2.set_ylim([0, mukbang_channels_df['videos_count'].max() / 100])

plt.savefig('./../src/graph/test_graph.png',
            facecolor='#ffffff',
            edgecolor='black',
            format='png', dpi=200)
plt.show()

# %%
film_channels_df['total_views_10000000'] = film_channels_df['total_views'] // 10000000

film_channels_df['subscribers_count_100000'] = film_channels_df['subscribers_count'] // 100000

film_channels_df
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_34564/3946879918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_channels_df['total_views_10000000'] = film_channels_df['total_views'] // 10000000
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_34564/3946879918.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_channels_df['subscribers_count_100000'] = film_channels_df['subscribers_count'] // 100000
# ...

# %%
import numpy as np

w = 0.15
nrow = film_channels_df.shape[0] # 행의 갯수
idx = np.arange(nrow)

fig, ax1 = plt.subplots(figsize = (15, 5))

# 첫번째 y축: Subscribers와 Videos
ax1.bar(idx - 2 * w, film_channels_df['subscribers_count_100000'], width = w, label='Subscibers')
ax1.bar(idx - w, film_channels_df['videos_count'], width = w, label='Videos')
ax1.set_ylabel('Subscribers (Ten Thousand) / Videos', fontsize=12)

# 두번째 y축: Total Views
ax2 = ax1.twinx()
ax2.bar(idx + w, film_channels_df['total_views_10000000'], width = w, label='Total Views', color='orange')
ax2.set_ylabel('Total Views (Million)', fontsize=12)

# x축, 타이틀, 범례
plt.xticks(idx, film_channels_df['channel_name'], rotation = 30)
plt.title('영화 유튜버 순위', fontsize=16)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# y축 범위
ax1.set_ylim([0, max(mukbang_channels_df['subscribers_count_100000'].min(),
                     mukbang_channels_df['videos_count'].min())])
ax2.set_ylim([0, mukbang_channels_df['total_views_10000000'].min()])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subscribers_count_100000'
#
# ...

# %%
animal_channels_df = channel_df[channel_df['category'] == 'ANIMAL']

animal_channels_df['total_views_10000000'] = animal_channels_df['total_views'] // 10000000

animal_channels_df['subscribers_count_100000'] = animal_channels_df['subscribers_count'] // 100000

animal_channels_df
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_34564/4026215659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   animal_channels_df['total_views_10000000'] = animal_channels_df['total_views'] // 10000000
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_34564/4026215659.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   animal_channels_df['subscribers_count_100000'] = animal_channels_df['subscribers_count'] // 100000
# ...

# %%
import numpy as np

w = 0.15
nrow = animal_channels_df.shape[0] # 행의 갯수
idx = np.arange(nrow)

fig, ax1 = plt.subplots(figsize = (20, 10))

# 첫번째 y축: Subscribers와 Videos
ax1.bar(idx - 2 * w, animal_channels_df['subscribers_count_100000'], width = w, label='Subscibers')
ax1.bar(idx - w, animal_channels_df['videos_count'], width = w, label='Videos')
ax1.set_ylabel('Subscribers (Ten Thousand) / Videos', fontsize=12)

# 두번째 y축: Total Views
ax2 = ax1.twinx()
ax2.bar(idx + w, animal_channels_df['total_views_10000000'], width = w, label='Total Views', color='orange')
ax2.set_ylabel('Total Views (Million)', fontsize=12)

# x축, 타이틀, 범례
plt.xticks(idx, animal_channels_df['channel_name'], rotation = 30)
plt.title('영화 유튜버 순위', fontsize=16)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# y축 범위
ax1.set_ylim([0, max(animal_channels_df['subscribers_count_100000'].min(),
                     animal_channels_df['videos_count'].min())])
ax2.set_ylim([0, animal_channels_df['total_views_10000000'].min()])

plt.show()

# %%
animal_channels_df
# Out:
#   category                channel_id        channel_name  \
# 0   ANIMAL  UC22go5LdQEw-iDuxFb4C0hw     SBS TV동물농장x애니멀봐
# 1   ANIMAL  UCmLiSrat4HW2k07ahKEJo4w              크림히어로즈
# 2   ANIMAL  UCLsj_Re3SxtkbZfX_ypY1eQ        수리노을SuriNoel
# 3   ANIMAL  UCYaBl0gtXV_3sHW4bQjq0hA              22똥괭이네
# 4   ANIMAL  UC29-IlHm6kbDB1ox8GthODw                 매탈남
# 5   ANIMAL  UCP1CQH2PVJv4-glNTuVJl3g  밀키복이탄이MilkyBokiTan
# 6   ANIMAL  UCij19II32Olbu8_vghmYNCA   슈앤트리 SHU AND TREE
# 7   ANIMAL  UCOv1v2iptqYMVEwLAIUOhPw                 정브르
# 8   ANIMAL  UCwl9OALh8IMwSv_kFdHlMDA                  다흑
# 9   ANIMAL  UCOp66Vup07X0YziXaaxqs2A             haha ha
#
#                                         channel_logo  subscribers_count  \
# 0  https://yt3.ggpht.com/PFxInKn471tSEbMbVYjD6ywZ...            4830000
# 1  https://yt3.ggpht.com/NYqzhjbY6EYcolCeLPgieC1K...            3770000
# 2  https://yt3.ggpht.com/ytc/AGIKgqN9sg6j8ozR0zPo...            2130000
# ...

# %% [markdown]
# - 먹방 카테고리 및 구독자의 수가 월등히 높음 > 1000000(쳔만)으로 나눔
# - 단위 통합을 하기 위해 다른 카테고리에도 구독자와 조회수에 각각 천만으로 나누니, 단위가 일치하지 않음...
# - 단위 수만 범례에 잘 정리하고 단위는 카테고리에 따라 알아서 나누는 것으로 할까요?
#
# - 구독자 수... >> 조회수만큼 높아요
# - 총 조회수를 총 영상수로 나눠서 평균 조회수로 보여주는 건 어떤지
#
# - 총 조회수를 영상 수로 나누면 >> 구독자 수랑 비슷한 숫자로 떨어짐 >> 확인 필요!
# - 구독자 수와 평균 조회수 > 막대그래프로 보여주고
# - 유의미한... 정보를

# %% [markdown]
# # 정리

# %% [markdown]
# ### 카테고리별 유튜버 순위 비교

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams['font.family'] = 'AppleGothic'

channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

category_dict = {'ANIMAL': '동물', 'FILM': '영화', 'SPORT': '스포츠',
                 'GAMING': '게임', 'MUKBANG': '먹방'}


def get_youtuber_rank_graph(category, category_name):
    df = channel_df[channel_df['category'] == category]

    if category == 'FILM':
        category = 'MOVIE'
    elif category == 'SPORT':
        category = 'SPORTS'
    elif category == 'GAMING':
        category = 'GAME'

    # 총 조회수 / 총 비디오 개수
    df['total_views_per_videos'] = (df['total_views'] // df['videos_count']) // 100000

    # 구독자 수 / 십만
    df['subscribers_count_100000'] = df['subscribers_count'] // 100000

    w = 0.15
    nrow = df.shape[0] # 행의 갯수
    idx = np.arange(nrow)

    fig, ax1 = plt.subplots(figsize = (20, 10))

    # 첫번째 y축: Subscribers와 Videos
    ax1.bar(idx - 2 * w, df['subscribers_count_100000'], width = w, label='구독자 수(단위: 십만)', color='#aec7e8')
    ax1.bar(idx - w, df['total_views_per_videos'], width = w, label='평균 조회 수(단위: 십만)', color='#FF69B4')
    ax1.set_ylabel('구독자 수(단위: 백만) / 평균 조회 수(단위: 십만)', fontsize=12)

    # 두번째 y축: Total Views
    ax2 = ax1.twinx()
    ax2.bar(idx, df['videos_count'] / 100, width = w, label='업로드 빈도율(단위: %)', color='#00FF7F')
    ax2.set_ylabel('업로드 빈도율(단위 : %)', fontsize=12)

    # x축, 타이틀, 범례
    plt.xticks(idx, df['channel_name'], rotation = 30)
    plt.title(category_name +' 유튜버 순위', fontsize=16)
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')

    # y축 범위


    ax1_max = max(df['subscribers_count_100000'].max(),df['total_views_per_videos'].max())

    ax1_min = min(df['subscribers_count_100000'].min(),df['total_views_per_videos'].min())
    ax1_range = ax1_max - ax1_min
    ax1.set_ylim([0, ax1_max + 0.1 * ax1_range])

    ax2.set_ylim([0, df['videos_count'].max() / 100])

    plt.savefig('./../src/graph/{0}/{0}_CHANNEL_YOUTUBER_GRAPH.png'.format(category),
                facecolor='#ffffff',
                edgecolor='black',
                format='png', dpi=200)
    plt.show()

# %%
for category, name in category_dict.items():
    get_youtuber_rank_graph(category, name)
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1671654653.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_views_per_videos'] = (df['total_views'] // df['videos_count']) // 100000
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1671654653.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['subscribers_count_100000'] = df['subscribers_count'] // 100000

# %% [markdown]
# ## 유튜버별 데이터 추이

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 786 entries, 2023-05-02 13:39:16 to 2023-01-17 13:00:10
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   channel_id         786 non-null    object
#  1   video_title        786 non-null    object
#  2   video_thumbnail    786 non-null    object
#  3   video_url          786 non-null    object
#  4   view_count         786 non-null    int64
#  5   like_count         786 non-null    int64
#  6   comment_count      786 non-null    int64
#  7   hashtag            785 non-null    object
#  8   category           786 non-null    object
#  9   channel_name       786 non-null    object
#  10  channel_logo       786 non-null    object
#  11  subscribers_count  786 non-null    int64
#  12  videos_count       786 non-null    int64
#  13  total_views        786 non-null    int64
# dtypes: int64(6), object(8)
# memory usage: 108.3+ KB

# %%
import re

def preprocess_df(df):

    # T, Z 지우기
    df['uploaded_date'] = [re.sub('[A-Z]'," ",s) for s in df['uploaded_date']]
    # Z 공백 제거
    df['uploaded_date'] = df['uploaded_date'].str.rstrip()

    # 포맷 바꾸기
    df['uploaded_date'] =pd.to_datetime(df['uploaded_date'],
                                      format='%Y-%m-%d', errors='raise')
    df['like_count'] = pd.to_numeric(df['like_count'], errors='coerce').fillna(0).astype(int)

    df['date'] = df['uploaded_date'].dt.date
    # datetime - index설정  (resample사용하기 위해 - 안그러면 에러나옴)
    df = df.set_index('uploaded_date')

    return df

# %%
# mukbang_df랑 channel_df 조인하기
import matplotlib.dates as mdates


def get_youtuber_video_rank_graph(category, channel_id):

    if category == 'FILM':
        category = 'MOVIE'
    elif category == 'SPORT':
        category = 'SPORTS'
    elif category == 'GAMING':
        category = 'GAME'

    df = pd.read_csv('./../src/{}_CHANNEL_VIDEO_INFO.csv'.format(category), encoding='utf-8', index_col=0)
    channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

    merged_df = pd.merge(df, channel_df, left_on='channel_id', right_on='channel_id', how='left')

    merged_df = preprocess_df(merged_df)
    print(merged_df)

    # 최근 한달 데이터 추출
    one_month_ago = pd.Timestamp.today().normalize() - pd.Timedelta(days=30)
    df_days = merged_df.loc[one_month_ago.strftime('%Y-%m-%d'):]
    df_days = df_days[df_days['channel_id'] == channel_id]

    df_days['views_per_subscriber'] = df_days['view_count'] / df_days['subscribers_count'] * 100
    df_days['likes_per_views'] = (df_days['like_count'] / df_days['view_count']) * 100
    df_days['views_10000'] = df_days['view_count'] / 10000

    df_days = df_days.groupby('date').mean()

    last_30_days = df_days[pd.to_datetime(df_days.index) >= datetime.today() - timedelta(days=30)]


    n_bars = len(last_30_days)
    if n_bars == 1:
        bar_width = 15 / n_bars
    else:
        bar_width = 0.5


    # 그래프 그리기
    fig, ax1 = plt.subplots(figsize=(20, 10))
    ax2 = ax1.twinx() # 두번째 y축 생성

    ax1.bar(last_30_days.index, last_30_days['views_10000'], color='#aec7e8', label='조회 수(단위: 만)', width=0.3)
    ax2.plot(last_30_days.index, last_30_days['likes_per_views'], color='#FF69B4', label='조회수 대비 좋아요 수 비율(단위: %)', linewidth=2)
    ax2.plot(last_30_days.index, last_30_days['views_per_subscriber'], color='#00FF7F', alpha=0.5, label='구독자 대비 조회율(단위: %)', linewidth=2)

    ax1.set_xlabel('날짜')
    ax1.set_ylabel('조회 수(단위: 만)')
    ax2.set_ylabel('조회수 대비 좋아요 수 비율(단위: %)/구독자 대비 조회율(단위: %)')

    try:
        # 조회수 y축 범위 설정
        ax1.set_ylim([0, last_30_days['views_10000'].max() * 1.2])

        ax1.tick_params(axis='x', rotation=45)
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%y/%m/%d')) # x축 날짜 라벨 형식 설정
        ax1.grid(True, axis='both', which='both')

        # 좋아요 y축 범위 설정
        ax2_max = last_30_days[['likes_per_views', 'views_per_subscriber']].max().max()
        ax2_min = last_30_days[['likes_per_views', 'views_per_subscriber']].min().min()
        ax2_range = ax2_max - ax2_min
        ax2.set_ylim([ax2_min - 0.1 * ax2_range, ax2_max + 0.1 * ax2_range])

        # 범례 추가
        youtuber_name = channel_df[channel_df['channel_id'] == channel_id]['channel_name'].values[0]
        plt.title(youtuber_name + '의 날짜별 데이터 추이', fontsize=16)
        ax1.legend(loc='upper left')
        ax2.legend(loc='upper right')

        plt.savefig('./../src/graph/test_graph.png',
                    facecolor='#ffffff',
                    edgecolor='black',
                    format='png', dpi=200)
        plt.show()
    except ValueError:
        pass

# %%
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

categories = ['ANIMAL', 'FILM', 'SPORT', 'GAMING', 'MUKBANG']
for category in categories:
    id_list = channel_df[channel_df['category'] == category]['channel_id'].values.tolist()
    for id in id_list:
        get_youtuber_video_rank_graph(category, id)
# Out:
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/1216795960.py:22: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_days = merged_df.loc[one_month_ago.strftime('%Y-%m-%d'):]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_3821/2484328476.py in <module>
#       5     id_list = channel_df[channel_df['category'] == category]['channel_id'].values.tolist()
#       6     for id in id_list:
# ----> 7         get_youtuber_video_rank_graph(category, id)
#
# ...

# %%
# mukbang_df랑 channel_df 조인하기
def get_youtuber_video_rank_graph_test(category, channel_id):

    if category == 'FILM':
        category = 'MOVIE'
    elif category == 'SPORT':
        category = 'SPORTS'
    elif category == 'GAMING':
        category = 'GAME'

    df = pd.read_csv('./../src/{}_CHANNEL_VIDEO_INFO.csv'.format(category), encoding='utf-8', index_col=0)
    channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

    merged_df = pd.merge(df, channel_df, left_on='channel_id', right_on='channel_id', how='left')

    merged_df = preprocess_df(merged_df)

    # 최근 한달 데이터 추출
    one_month_ago = pd.Timestamp.today().normalize() - pd.Timedelta(days=30)
    df_days = merged_df.loc[one_month_ago.strftime('%Y-%m-%d'):]
    df_days = df_days[df_days['channel_id'] == channel_id]

    df_days['views_per_subscriber'] = df_days['view_count'] / df_days['subscribers_count'] * 100
    df_days['likes_per_views'] = (df_days['like_count'] / df_days['view_count']) * 100
    df_days['views_10000'] = df_days['view_count'] / 10000

    df_days = df_days.groupby('date').mean()

    last_30_days = df_days[pd.to_datetime(df_days.index) >= datetime.today() - timedelta(days=30)]

    n_bars = len(last_30_days)

    if n_bars == 1:
        bar_width = 3 / n_bars
    else:
        bar_width = 0.5

    # 그래프 그리기
    fig, ax1 = plt.subplots(figsize=(15, 10))
    ax2 = ax1.twinx() # 두번째 y축 생성

    ax1.bar(last_30_days.index, last_30_days['views_10000'], color='#aec7e8', label='조회 수(단위: 만)', width=0.3)
    ax2.plot(last_30_days.index, last_30_days['likes_per_views'], color='#FF69B4', label='조회수 대비 좋아요 수 비율(단위: %)', linewidth=2)
    ax2.plot(last_30_days.index, last_30_days['views_per_subscriber'], color='#00FF7F', alpha=0.5, label='구독자 대비 조회율(단위: %)', linewidth=2)

    ax1.set_xlabel('날짜')
    ax1.set_ylabel('조회 수(단위: 만)')
    ax2.set_ylabel('조회수 대비 좋아요 수 비율(단위: %)/구독자 대비 조회율(단위: %)')

    try:
        # 조회수 y축 범위 설정
        ax1.set_ylim([0, last_30_days['views_10000'].max() * 1.2])

        ax1.tick_params(axis='x', rotation=45)
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%y/%m/%d')) # x축 날짜 라벨 형식 설정
        ax1.grid(True, axis='both', which='both')

        # 좋아요 y축 범위 설정
        ax2_max = last_30_days[['likes_per_views', 'views_per_subscriber']].max().max()
        ax2_min = last_30_days[['likes_per_views', 'views_per_subscriber']].min().min()
        ax2_range = ax2_max - ax2_min
        ax2.set_ylim([ax2_min - 0.1 * ax2_range, ax2_max + 0.1 * ax2_range])

        # 범례 추가
        youtuber_name = channel_df[channel_df['channel_id'] == channel_id]['channel_name'].values[0]
        plt.title(youtuber_name + '의 날짜별 데이터 추이', fontsize=16)
        ax1.legend(loc='upper left')
        ax2.legend(loc='upper right')

        plt.savefig('./../src/graph/{}/{}_VIDEO_GRAPH_DATE.png'.format(category, channel_id),
                    facecolor='#ffffff',
                    edgecolor='black',
                    format='png', dpi=200)
        plt.show()

    except ValueError:
        pass

# %%
channel_df = pd.read_csv('./../src/TB_CHANNEL_INFO.csv', encoding='utf-8', index_col=0)

categories = ['GAMING', 'FILM', 'SPORT']
for category in categories:
    id_list = channel_df[channel_df['category'] == category]['channel_id'].values.tolist()

    for id in id_list:
        get_youtuber_video_rank_graph_test(category, id)
# Out:
#                                    channel_id  \
# uploaded_date
# 2023-05-01 02:30:12  UC2NFRq9s2neD_Ml0tPhNC2Q
# 2023-04-30 02:30:09  UC2NFRq9s2neD_Ml0tPhNC2Q
# 2023-04-29 02:30:30  UC2NFRq9s2neD_Ml0tPhNC2Q
# 2023-04-28 02:30:09  UC2NFRq9s2neD_Ml0tPhNC2Q
# 2023-04-27 02:30:18  UC2NFRq9s2neD_Ml0tPhNC2Q
# ...                                       ...
# 2023-02-23 22:00:02  UCNzcxCN_Hh_lu5RCSFXKgGQ
# 2023-02-22 22:00:01  UCNzcxCN_Hh_lu5RCSFXKgGQ
# 2023-02-21 22:00:07  UCNzcxCN_Hh_lu5RCSFXKgGQ
# 2023-02-20 22:00:09  UCNzcxCN_Hh_lu5RCSFXKgGQ
# 2023-02-20 10:00:16  UCNzcxCN_Hh_lu5RCSFXKgGQ
#
#                                                            video_title  \
# uploaded_date
# 2023-05-01 02:30:12                           100년에 한번 나올까 말까 한 레전드 게임
# 2023-04-30 02:30:09                게임을 넘 재밌개해서 선물 보내드리려고요. 개발자님 주소좀^_^
# 2023-04-29 02:30:30                                 (소름주의) 돈미새 #shorts
# 2023-04-28 02:30:09                                  당신이 차인 이유 #shorts
# ...
