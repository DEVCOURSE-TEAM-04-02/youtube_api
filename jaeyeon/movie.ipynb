# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

DEVELOPER_KEY='AIzaSyDfvhCHcNTn5RB30Ll9oFSjnvjW9x1ncLs' # 내 API 키값 입력
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube=build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
youtuber = ["지무비 : G Movie","고몽","김시선","드림텔러(DreamTeller)","B Man 삐맨"]
channel_id=[]
subscriber=[]

for i in range(5):
    search_response=youtube.search().list(
        q=youtuber[i],
        order='relevance',
        part='snippet',
        maxResults=1,
        ).execute()
    channel_id.append(search_response['items'][0]['id']['channelId'])

    channel_response = youtube.channels().list(
        id=search_response["items"][0]["snippet"]["channelId"],
        part="statistics"
    ).execute()
    subscriber.append(channel_response['items'][0]['statistics']['subscriberCount'])

channel_id
subscriber
# Out:
# ['2870000', '2200000', '1580000', '1120000', '1180000']

# %%
playlists=[]
for i in range(5):
    playlists.append(youtube.playlists().list(
        channelId= channel_id[i],
        part = "snippet",
        maxResults=50
    ).execute())

# %%
import pandas as pd
pids=[]
#playlists[0]['items'][36]['snippet']['title']
#playlists[1]['items'][22]['snippet']['title']
#playlists[2]['items'][8]['snippet']['title']
#playlists[3]['items'][2]['snippet']['title']
#playlists[4]['items'][6]['snippet']['title']
pids.append(playlists[0]['items'][36]['id'])
pids.append(playlists[1]['items'][21]['id'])
pids.append(playlists[2]['items'][8]['id'])
pids.append(playlists[3]['items'][2]['id'])
pids.append(playlists[4]['items'][6]['id'])
pids
# Out:
# ['PLvbMzS0jd5PhqBlDYyg9SPUi67-_0TN78',
#  'PLHgLGdBMAAYdXXSFCPasx71ah9X-CK15f',
#  'PLK46iOSPNQ5MBoa5YR8Jh6tU7H2xGE_rY',
#  'PLxF5TL6uT-y7yY0WvJdB3Z4yjxGHJgxeE',
#  'PLMNlAvDmnfgl8hW2lZRF0pUEdcI5Z3FIJ']

# %%
playlistitems_list_response=[]
for i in range(5):
    playlist_videos=youtube.playlistItems().list(
        playlistId= pids[i],
        part = "snippet",
        maxResults=10,
    )
    playlistitems_list_response.append(playlist_videos.execute())
playlistitems_list_response
# Out:
# [{'kind': 'youtube#playlistItemListResponse',
#   'etag': 'yUtRpwVq4kiE7soG6O_DQLzspHE',
#   'nextPageToken': 'EAAaBlBUOkNBbw',
#   'items': [{'kind': 'youtube#playlistItem',
#     'etag': 'oAhZyC-68kQmLoFZg_xj_J5pfII',
#     'id': 'UEx2Yk16UzBqZDVQaHFCbERZeWc5U1BVaTY3LV8wVE43OC41RDUzRjJFQ0Y0MUI3NzU1',
#     'snippet': {'publishedAt': '2019-06-15T00:29:10Z',
#      'channelId': 'UCaHGOzOyeYzLQeKsVkfLEGA',
#      'title': '인류 멸망 후 태어난(?) 아기의 충격적 비밀',
#      'description': '영화 ‘나의마더‘입니다. \n#지무비 #영화 #나의마더\n[지무비 채널 멤버십 가입]\nhttps://goo.gl/LrQJgy\n[지무비 구독] \nhttps://goo.gl/4ETvXY\n[지무비 공식 인스타그램] \nhttps://www.instagram.com/G_movie__/\n[지무비 개인 인스타그램] \nhttps://www.instagram.com/awayout1/\n[다른 영화 소개 둘러보기]\nhttps://goo.gl/78TM8K\n[지무비 후원] \nhttps://toon.at/donate/636671533566619411\n[지무비 페이스북] \nhttps://www.facebook.com/pg/Gmoviee\n[이메일] \nawayout2@naver.com',
#      'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A530cGu7JkM/default.jpg',
#        'width': 120,
# ...

# %%
video_names=[]
video_ids=[]
date=[]
for i in range(5):
    for v in playlistitems_list_response[i]['items']:
        video_names.append(v['snippet']['title'])
        video_ids.append(v['snippet']['resourceId']['videoId'])
        date.append(v['snippet']['publishedAt'])
        
vdf=pd.DataFrame([date,video_names,video_ids]).T
vdf.columns=['Date','Title','IDS']
vdf
# Out:
#                     Date                                              Title
# 0   2019-06-15T00:29:10Z                          인류 멸망 후 태어난(?) 아기의 충격적 비밀  \
# 1   2019-03-02T05:13:07Z                    수갑채워놨는데 남편이 심장마비로 사망하면 벌어지는 대참사
# 2   2019-01-18T08:38:02Z                  위장수사로 치킨집 열었다가 맛집으로 소문나면 벌어지는 일..
# 3   2018-07-18T03:08:22Z                           상상도 못할 일만 벌어지는 쓰레기 변태 학교
# 4   2018-02-17T15:35:40Z                             대한민국 영화계를 끝장낼뻔한 전설의 망작
# 5   2018-08-04T03:51:32Z                         1000살 냉동인간이 마주친 최악의 새 인류..
# 6   2018-10-05T21:23:49Z                          보기만 해도 미칠 것 같은 미래의 감옥시스템들
# 7   2019-12-02T16:18:40Z                         싸이코패스와 소시오패스가 사귀면 벌어지는 일..
# 8   2022-09-16T07:55:56Z     와.. 단언컨대 한국 영화 역사상 최고 수위의 역대급 미친 영화..ㄷㄷ 《늑대사냥》
# 9   2018-09-07T13:45:03Z                       물고기들이 다리가 생기면 벌어지는 역대급 대참사..
# 10  2023-04-16T02:54:28Z  우영우 방송사에서 또 올해 최고 대.꿀.잼 드라마 뽑았다..ㄷㄷ 전국구 일타 연애 ...
# ...

# %%
import re

ids=[]
category_id=[]
views=[]
likes=[]
comments=[]
mins =[]
seconds=[]
title=[]
subscribers=[]

for u in range(len(vdf)):
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=vdf['IDS'][u]
    )
    try:
        response = request.execute()
        
        if response['items']==[]:
            ids.append("-")
            category_id.append("-")
            views.append("-")
            likes.append("-")
            comments.append("-")

        else:
            title.append(response['items'][0]['snippet']['title'])
            category_id.append(response['items'][0]['snippet']['categoryId'])
            views.append(response['items'][0]['statistics']['viewCount'])
            likes.append(response['items'][0]['statistics']['likeCount'])
            comments.append(response['items'][0]['statistics']['commentCount'])
            subscribers.append(subscriber[u//10])

                
    except:
        likes.append("비공개")
        comments.append(response['items'][0]['statistics']['commentCount'])
        subscribers.append(subscriber[u//10])

# %%
gmovie_df=pd.DataFrame([title,category_id,views,likes,comments,subscribers]).T
gmovie_df.columns=['제목','카테고리','조회수','좋아요수','댓글수','구독자수']
gmovie_df
# Out:
#                                                    제목 카테고리       조회수   좋아요수
# 0                           인류 멸망 후 태어난(?) 아기의 충격적 비밀    1   4877381  40606  \
# 1                     수갑채워놨는데 남편이 심장마비로 사망하면 벌어지는 대참사    1  33932221    비공개
# 2                   위장수사로 치킨집 열었다가 맛집으로 소문나면 벌어지는 일..    1   8704112  64076
# 3                            상상도 못할 일만 벌어지는 쓰레기 변태 학교    1  10109205  46986
# 4                              대한민국 영화계를 끝장낼뻔한 전설의 망작    1   7889859  45235
# 5                          1000살 냉동인간이 마주친 최악의 새 인류..    1   7474625  36043
# 6                           보기만 해도 미칠 것 같은 미래의 감옥시스템들    1   7270611  37440
# 7                          싸이코패스와 소시오패스가 사귀면 벌어지는 일..    1   6519040  61093
# 8      와.. 단언컨대 한국 영화 역사상 최고 수위의 역대급 미친 영화..ㄷㄷ 《늑대사냥》    1   6291693  45550
# 9                        물고기들이 다리가 생기면 벌어지는 역대급 대참사..    1   5848457  36370
# 10  우영우 방송사에서 또 올해 최고 대.꿀.잼 드라마 뽑았다..ㄷㄷ 전국구 일타 연애 ...    1   1379481   7176
# ...
