# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Hannanum

def get_wordCloud(tuples):
    """
    Make WordCloud
    여러개의 문자열로 이루어진 튜플을 인자로 받는다.
    만들어진 img를 리턴한다.
    """
    # 하나의 문자열로 만들어주는 작업 / 튜플안에서 튜플꺼내기
    longStr = ''.join([text for tuple in tuples for text in tuple])

    # 형태소 분석 및 카운터
    hannanum = Hannanum()
    titleNouns = hannanum.nouns(longStr)
    titleCounter = Counter(titleNouns)

    wordcloud = WordCloud(
        font_path ="./malgun.ttf",
        width=1000,
        height=400,
        max_words=100,
        prefer_horizontal=1,
        max_font_size=200,
    )

    img = wordcloud.generate_from_frequencies(titleCounter)
    return img

# %%
# DB
import pymysql as db
import pprint

local = 'team0402.c43ypw0liaa2.ap-northeast-2.rds.amazonaws.com'  # aws rds 접근
con = db.connect(
    host=local,
    user='team0402',
    db='Team0402_Youtube',
    password='team0402',
    charset='utf8mb4'
)
cur = con.cursor()

def get_result_byQuery(query):
    cur.execute(query)
    return cur.fetchall()

# %%
# 각 카테고리에서 상위 조회수 영상 100개 제목 WordCloud
# 결과물을 저장
category_names = ['ANIMAL', 'GAME', 'MOVIE', 'MUKBANG', 'SPORTS']

for category in category_names:
    query_result = get_result_byQuery(
        """
        SELECT v.video_title
        FROM TB_CHANNEL_INFO as ch
        INNER JOIN TB_VIDEO_INFO as v ON ch.channel_id = v.channel_id
        WHERE ch.category = '{}'
        ORDER BY v.view_count desc LIMIT 100;
        """.format(category)
    )
    plt.imshow(get_wordCloud(query_result))
    plt.savefig('wordcloud/{}/{}_CHANNEL_VIDEO_WORDCLOUD.png'.format(category, category))

# %%
# 각 카테고리에서 상위 조회수 영상 100개의 덧글 WordCloud
# 결과물을 저장
for category in category_names:
    query_result = get_result_byQuery(
        """
        SELECT cmt.content
        FROM TB_CHANNEL_INFO as ch
        INNER JOIN TB_VIDEO_INFO as v ON ch.channel_id = v.channel_id
        INNER JOIN TB_COMMENT_INFO as cmt ON v.video_id = cmt.video_id
        WHERE ch.category = '{}'
        ORDER BY v.view_count desc LIMIT 500;
        """.format(category)
    )
    plt.imshow(get_wordCloud(query_result))
    plt.savefig('wordcloud/{}/{}_CHANNEL_COMMENT_WORDCLOUD.png'.format(category,category))

# %%
# 각 카테고리별 가장 인기 많았던 댓글 3개
for category in category_names:
    query_result = get_result_byQuery(
        """
        SELECT cmt.content
        FROM TB_CHANNEL_INFO as ch
        INNER JOIN TB_VIDEO_INFO as v ON ch.channel_id = v.channel_id
        INNER JOIN TB_COMMENT_INFO as cmt ON v.video_id = cmt.video_id
        WHERE ch.category = '{}'
        ORDER BY cmt.like_count desc LIMIT 3;
        """.format(category)
    )
    print("\n----------{}----------\n".format(category))
    pprint.pprint(query_result)
# Out:
# ----------ANIMAL----------
#
# (('동물들은 호흡이나 냄새 온도등으로 위급상황을 판단한답니다 심지어 심장 박동이나 배설물의 냄새로도 판단한다고하니 동물입장에서는 “오늘 '
#   '밥은 좀 새롭게 주네” 수준이었을겁니다!',),
#  ('처음엔 미안해서 달래줬지만 엄살이 심한걸 보고 “히융~” 가서 가버린게 학계의 정설입니다.',),
#  ('썸넬보고 얼척없어서 달려왔어요 ㅋㅋㅋㅋㅋㅋ😂',))
#
# ----------GAME----------
#
# (('하마의 심리를 파악해서 함정을 만들어두신 독사분도 대단하시고 혹시 독사분이 서운하실까봐 모든 함정에 걸리는 하마형도 너무 '
#   '웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('지켜줘야 할 것 같은 남자 1위ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('진짜 저 거위는 언제봐도 웃음버튼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',))
#
# ----------MOVIE----------
#
# (('이게 엄청 옛날도 아닌 100년정도 밖에 안된일이라는게 소름입니다…😭',),
#  ('이런건 넷플릭스에 올라왔으면 좋겠네요.. 전세계 인이 볼수 있게..',),
#  ('모든 회사는 경비가 cctv가 있습니다. 저런 경우 대리부터 짜릅니다.',))
#
# ----------MUKBANG----------
#
# (('Getting recognized by Gordon Ramsay is awesome, meeting him in person and '
#   'being invited for a taste test of a new burger is another level of '
#   'awesomeness… ❤',),
#  ('Tzuyang is now being recognize as a food critic and not just being a '
#   'mukbanger. She gives honest opinions with the food she eats and being '
#   'recognized by gordon ramsay is a whole another level. Great respect to her '
#   'since she really love food. I really enjoyed her vids.',),
#  ('진짜 대창먹방은 대단하다.. 유튜버들 개맛있게 먹어서 따라해봤는데 한줄도 못먹겠고 너무 느끼해서 바로 라면끓임',))
#
# ----------SPORTS----------
#
# (('하이큐보다 더 비현실적인 설정은 김연경 선수죠\n'
#   '중학교때까지 키가 작아서 리베로, 세터하다가 갑자기 20cm 크고 고등학생 신분으로 성인 국가대표 씹어먹고 프로 데뷔하자마자 전 시즌 '
#   '꼴찌팀 우승시키고 6관왕(신인상, 득점상, 공격상, 서브상, 정규리그 mvp, 챔피언결정전 mvp)!\n'
#   '3번의 무릎 수술, 흥국생명과의 소송, 배협의 열악한 지원 등 많은 고난이 있었지만 그걸 이겨내고 매시즌 트로피와 상을 받고 메달 따지 '
#   '못했는데도 런던올림픽 mvp  & 득점 세계신기록 보유! \n'
#   '클럽 경기에서 최고의 대회라고 뽑히는 유럽 챔피언스리그에서도 MVP & 동양인 최초로 유럽팀 주장까지!',),
#  ('누가봐도 알리 연경언니한테 한국어 배웠음.. 인중때려버린다라니... ㅠㅠㅋㅋㅋㅋㅋㅋ',),
#  ('가볍게 양갱먹고 퇴소한 성엽이형 개추 ㅋㅋ',))

# %%
# 특정 유튜버 모든 영상에서 가장 많이 나온 제목 WordCloud
# 결과물을 저장

for category in category_names:
    channel_ids_inCategory = get_result_byQuery(
        """
        SELECT channel_id
        FROM TB_CHANNEL_INFO
        WHERE category ='{}'
        """.format(category)
    )

    for channel_id in channel_ids_inCategory:
        query_result = get_result_byQuery(
            """
            SELECT video_title
            FROM TB_VIDEO_INFO
            WHERE channel_id = '{}'
            """.format(channel_id[0])
        )
        plt.imshow(get_wordCloud(query_result))
        plt.savefig('wordcloud/{}/{}_TITLE_WORDCLOUD.png'.format(category,channel_id[0]))

# %%
# 특정 유튜버 모든 영상에서 가장 많이 나온 댓글 WordCloud
# 결과물을 저장

for category in category_names:
    channel_ids_inCategory = get_result_byQuery(
        """
        SELECT channel_id
        FROM TB_CHANNEL_INFO
        WHERE category ='{}'
        """.format(category)
    )

    for channel_id in channel_ids_inCategory:
        query_result = get_result_byQuery(
            """
            SELECT cmt.content
            FROM TB_VIDEO_INFO as v
            INNER JOIN TB_COMMENT_INFO as cmt ON v.video_id = cmt.video_id
            WHERE v.channel_id = '{}'
            """.format(channel_id[0])
        )
        plt.imshow(get_wordCloud(query_result))
        plt.savefig('wordcloud/{}/{}_COMMENT_WORDCLOUD.png'.format(category,channel_id[0]))

# %%
# 각 유튜버별 가장 인기 많았던 댓글 3개
for category in category_names:
    channel_ids_inCategory = get_result_byQuery(
        """
        SELECT channel_id
        FROM TB_CHANNEL_INFO
        WHERE category ='{}'
        """.format(category)
    )
    print("{}".format(category))
    for channel_id in channel_ids_inCategory:
        query_result = get_result_byQuery(
            """
            SELECT cmt.content
            FROM TB_VIDEO_INFO as v
            INNER JOIN TB_COMMENT_INFO as cmt ON v.video_id = cmt.video_id
            WHERE v.channel_id = '{}'
            ORDER BY cmt.like_count DESC LIMIT 3
            """.format(channel_id[0])
        )
        print("\n----------{}----------\n".format(channel_id[0]))
        pprint.pprint(query_result)
# Out:
# ANIMAL
#
# ----------UC22go5LdQEw-iDuxFb4C0hw----------
#
# (('3년후도 아니고 13년후라니 넘 감동스럽....뚠냥이로 잘 성장해주었군 ㅠㅠ 보호자님께 감사드립니다.',),
#  ('진짜 구조해 주시고 치료해 주셔서 감사합니다.  눈물이 멈추질 않네요. 널 그렇게 만든 짐승보다 못한 인간은 천벌을 받을꺼야. 꼭 '
#   '힘내렴 아가야🫂',),
#  ('얼마나 소리를 질렀으면 목이 다 쉬었네..',))
#
# ----------UC29-IlHm6kbDB1ox8GthODw----------
#
# (('파이프 안에서 데려온 우리 누리즈들을 추억하며  😍',),
#  ('인생은 까칠이처럼\n'
#   '가족에게는 무니처럼\n'
#   '타인에게는 꼬리처럼\n'
#   '대답은 소시미처럼\n'
#   '집 고를 땐 누리처럼\n'
#   '엄마한텐 점남이처럼\n'
#   '효도는 다리처럼\n'
#   '적응은 쪼꾸미처럼\n'
#   '양보는 막내처럼\n'
#   '배고플땐 눈썹이처럼\n'
#   '동생한테는 이쁘이처럼\n'
#   '\n'
#   '이렇게 항상 누리네처럼 살고 싶네용💛🤍🐈',),
#  ('세상에.. 우리 막내.. 세상 무섭게 하악하다가도 집사님 손길은 받아들이고.. 너무너무 착한것같아요ㅜㅜ..',))
#
# ----------UCij19II32Olbu8_vghmYNCA----------
#
# (('왤케 사람처럼 앉아있엌ㅋㅋㅋㅋㅋ귀여워ㅠㅠㅠ',), ('강아지 귀에서 팽이버섯이 나오네',), ('마음깊이 진심으로 감사드립니다',))
#
# ----------UCLsj_Re3SxtkbZfX_ypY1eQ----------
#
# (('고양이 행동 분석가로써, 저 꼬마아이을 집사로 보는게 아니라 목숨걸고 보호해야될 대상으로 보는겁니다. 3번 돌려봤는데, 자는게 깨지 '
#   '않게끔 조심하는점 2마리는 아래에서 번갈아가며 순찰하거나 앉아서 사방을 주시하는등. 즉 저 꼬마아이를 지켜줘야할 대상으로 인식하고 있고 '
#   '꺴을때 냐아아아앙 하면서 반기는거 보면, 새끼처럼 지켜주는 대상이 아닌, 마치 여왕님처럼 생각하며 지켜주는겁니다. 남자아이니깐 '
#   '왕자님이라고 표현하면 되겠네요. 꼬마 왕자님으로 인식하고 있음으로 꼬마집사X 꼬마왕자님O 이게 맞습니다. 저 남자아이 복받았네요 ㅎㅎ '
#   '그리고 저런 아들을 두신 업로더분도 얼마나 복이 많으시길레 저리 이뿐 아기고양이마냥 귀여운 아드님을 두셨을까 >.<',),
#  ('Je pense que les chats ressentent que ce nest pas de la vraie '
#   'tristesse.😂😂😂',),
#  ('I’ve had depression my whole life and all my cats have noticed. They go out '
#   'of their way to be extra affectionate when I’m having a hard time.',))
#
# ----------UCmLiSrat4HW2k07ahKEJo4w----------
#
# (('현재 아이들은  병원진료 후 저희 쉼터에서 열심히 케어중에 있습니다 아이들의 소식이 업로드 예정이오니 많은 응원 부탁드립니다! \n'
#   'Currently, the children eat well at our shelter after receiving hospital '
#   'treatment and are somewhat healthy! I-News will be uploaded through our '
#   'channel soon, so please show a lot of support!',),
#  ('Hoomans : Only human can stand at two legs...\nLuLu : Hold my Snacks 😂',),
#  ('겸둥이들 MBTI는 CUTE 아니었나요?😍😍😍',))
#
# ----------UCOp66Vup07X0YziXaaxqs2A----------
#
# (('썸넬보고 얼척없어서 달려왔어요 ㅋㅋㅋㅋㅋㅋ😂',),
#  ('고양이한테 맞을 수 있대서 허겁지겁 달려왔습니다',),
#  ('You made them a waiting room while their mansion is being prepared how '
#   'nice.',))
#
# ----------UCOv1v2iptqYMVEwLAIUOhPw----------
#
# (('라기 너무 즐거웠어 츄베릎❤️',),
#  ('역시 모카가 브르삼촌을 기억하나봐요!\U0001fae2 출산 후에도 브르님을 경계안하고 오히려 반겨주는 모습에 신기하기도하고 괜히 제가 '
#   '뭉클했습니다\U0001f979\n'
#   '\n'
#   '영상 재밌게 잘볼게요🙋🏻\u200d♀️',),
#  ('엄마 물범 애기 어디 데려가는줄알고 허겁지겁 따라오는게 대단하기도하고 안쓰럽기도하고 미묘한감정이 드네요 물범 너무 이쁘요',))
#
# ----------UCP1CQH2PVJv4-glNTuVJl3g----------
#
# (('동물들은 호흡이나 냄새 온도등으로 위급상황을 판단한답니다 심지어 심장 박동이나 배설물의 냄새로도 판단한다고하니 동물입장에서는 “오늘 '
#   '밥은 좀 새롭게 주네” 수준이었을겁니다!',),
#  ('처음엔 미안해서 달래줬지만 엄살이 심한걸 보고 “히융~” 가서 가버린게 학계의 정설입니다.',),
#  ('뒷발이 너무 신기하네요. \n앞발 지나간 자리만 밟는 다는 느낌인가 보도 않고 걷는데 하나도 안넘어가',))
#
# ----------UCwl9OALh8IMwSv_kFdHlMDA----------
#
# (('낯선사람이 만지면서 뒤집는데도 똥도안싸고 엄청순하네요 ㅋㅋ 너무귀엽다',),
#  ('카피바라의 개인사육이 허가된건 나라에서도 얘는 키울수 있음 키워봐라ㅋ  이런 느낌이 아닐까 생각됩니다',),
#  ('옛날 청계천 애완동물 시장에 대한 농담 중에 "혹시 돌고래 있나요?" 물었더니 상인이 안에서 전화하고 오더니 "몇 달 걸리는데 '
#   '괜찮으세요?"  했다는게 있죠 ㅋㅋㅋㅋㅋ',))
#
# ----------UCYaBl0gtXV_3sHW4bQjq0hA----------
#
# (('저희 의료진들도 속으로 웃참🤣😂 했답니다 ㅋㅋㅋ (마스크가 있어 다행🤭)',),
#  ('아무도 웃지 않고 묵묵히 할일을 하실수 있죠?? 저였음 어깨 들썩였을듯 ㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('나가라니깐이 진짜 찐이네욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',))
# GAME
#
# ----------UC2NFRq9s2neD_Ml0tPhNC2Q----------
#
# (('하마의 심리를 파악해서 함정을 만들어두신 독사분도 대단하시고 혹시 독사분이 서운하실까봐 모든 함정에 걸리는 하마형도 너무 '
#   '웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('지켜줘야 할 것 같은 남자 1위ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('진짜 저 거위는 언제봐도 웃음버튼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',))
#
# ----------UCD2YO_A_PVMgMDN9jpRrpVA----------
#
# (('고맙다 찬호야 니 덕에 이 각박한 세상에 웃는다',),
#  ('랄로 공포겜 주기적으로 했으면 좋겠다 ㅈㄴ재밋네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('1년동안 이것만 기다린 랄뚜기면 개추 ㅋㅋㅋㅋ',))
#
# ----------UCDBAVzfX3yZ1hah0FHnOoaA----------
#
# (('물쥐형이 초대해주고 잘챙겨주고 놀아줘서 너무 즐거웠고 좋은추억 쌓았어 넘 고마워 잉 기모링ㅋㅋ',),
#  ('"근데 지환아 넌 모르잖아 그마 가는 세상" - 더 쥐로리 中',),
#  ('"절대 그마 실력 아닙니다"',))
#
# ----------UCfIUuMA7U_jImP7oWfTe4Pw----------
#
# (('상호야 너는 실력은 좋은데 팀이 안좋은 거 같아..',),
#  ('이상호의 전개에는 아무것도 없다.',),
#  ('이상호 우승하면 함시크머리 가겠습니다',))
#
# ----------UChQ-VMvdGrYZxviQVMTJOHg----------
#
# (('디스전때 "야이 개씨1발 조1빱 생퀴 넌 다이아 곡괭이로도 가뿐하지"ㅋㅋㅋㅋㅋㅋ아 벌써 행복하다ㅋㅋㅋㅋ',),
#  ('도티가 디스전하면 ㅋㅋㅋㅋㅋㅋㅋㅋ 개웃길것 같은데 ㅋㅋㅋㅋㅋ\n\n하지만 1차에서 바로 탈락!',),
#  ('지금 제작진 표정봐 미쳐',))
#
# ----------UCJpAwvQaZyCI5spAz7tipGA----------
#
# (('같이 러스트하면서 정말재밌게 했습니다 감사합니다 ㅠㅠ',), ('수능 대박 기원',), ('즐거운 설연휴 보내세요',))
#
# ----------UCNzcxCN_Hh_lu5RCSFXKgGQ----------
#
# (('축하해주신 쁠몬님들 넘 고마워용~~\n'
#   '와준 사장님이랑 블동부 샌박님덜 넘 감사하다는ㅎㅎ\n'
#   '5년동안 김블루블루사장님이랑 일하면서 희노애락을 같이 겪었는데 여길 다니면서 결혼까지 할줄이얌~~ 감회가 새롭습니다\n'
#   '저에게 170만 유튜버 편집자 타이틀을 달아준 블루블루 사장님 고맙읍니다 사..사.. 사는동안 많이버세요',),
#  ('괜찮아 형 팬은 172만이잖아',),
#  ('죽인다',))
#
# ----------UCpJw2H9KKqwCCGQKRh1Bf2w----------
#
# (('코르키 들어가니까 카이사가 나오네;;',),
#  ('뚝딱뚝딱 대본 읽는 우리혁ㅋㅋㅋㅋㅋㅋㅋㅋ 너무 귀엽자나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('요즘 많이 지친거같던데 응원합니다..',))
#
# ----------UCUbOogiD-4PKDqaJfSOTC0g----------
#
# (('녹화 끝나고 푸린 나가고 집에서 혼자 이 게임 켜봤을 테스터훈이면 개추',),
#  ('다시 올라가는게 ㅈㄴ웃기네 ㅋㅋㅋㅋ',),
#  ('관상부터 롤 존나 잘하게생겼네',))
#
# ----------UCYJ0Ucu9jPX5kn6SeDcNaIQ----------
#
# (('선수들이 포기를 안 했었는데 잠시 패배를 느꼈던 내가 미안해지게 되었던 진짜 명경기',),
#  ('이번만큼은 팀 상관없이 모두가 광동을 응원했다...',),
#  ('돌아온 마왕 페이커 (떠난적 없음)\r\n'
#   '라스트댄스 데프트 (라스트 아님)\r\n'
#   '마포고 매치 (둘다 졸업장 없음) \r\n'
#   '염소 vs 알파카 매치업은 정말 전설이다....',))
# MOVIE
#
# ----------UC79hJz6y1EEiIkwfHOuWC4w----------
#
# (('그놈의 촉법..누굴 지키겠다는건지..',),
#  ('난중일기에 보면 장군은 시도때도 없이 자주 아파 드러누으신 경우가 많고 , 부하들 눈을 피해   하인집에 가셔서 엉엉 운적이 여러번 '
#   '있으셨습니다...정말 인간적으로 얼마나 전쟁수행이 힘들고 수장으로서 견디기 힘들었는지 가늠이 안됩니다...',),
#  ('김혜수는 정말 대단함. 보는 순간 몰입감 장난 아님',))
#
# ----------UCaHGOzOyeYzLQeKsVkfLEGA----------
#
# (('어느 순간부터 남궁민하면 그냥 믿고 보게 됨 작품선정이나 특유의 딕션이랑 연기력이 드라마쪽에선 ㄹㅇ독보적 존재',),
#  ('역시 여긴 드라마 본편보다 편집이 존나 웃김ㅋㅋㅋㅋㅋㅋ',),
#  ('형...진짜 너무나도 실례되는 말인거 아는데 요즘 올리는 한국 드라마 영화도 진짜 재밌게 보고 있지만 광고 말고 형이 재밌게 봤던 '
#   '영화나 망작 리뷰도 가끔 해주면 안될까 ? 예전 초창기 지무비 감성이 그리워',))
#
# ----------UCJOTgAmY3S0mz-6imyhkj8g----------
#
# (('이게 엄청 옛날도 아닌 100년정도 밖에 안된일이라는게 소름입니다…😭',),
#  ('이런건 넷플릭스에 올라왔으면 좋겠네요.. 전세계 인이 볼수 있게..',),
#  ('노래 잘 하는 배우는 그 감정 전달력 진짜 무시 못 함 울컥',))
#
# ----------UCMguxwveCsLVpyKrLz-EFTg----------
#
# (('모든 회사는 경비가 cctv가 있습니다. 저런 경우 대리부터 짜릅니다.',),
#  ('의사소통을 못하나..? 여친 있어요 하면 갈거같은데 왜 저렇게 눈빛으로 대화하는건데. 물어본사람 무안하겠네. 대답도 안해주고..',),
#  ('알바니까 시끄럽지..\n정규직이 저래봐ㅋㅋㅋㅋㅋ',))
#
# ----------UCpcft4FJXgUjnxWoQYsl7Ug----------
#
# (('이거 학교 2013 + 동백꽃필무렵 + 스카이캐슬 합쳐 놓은 스토리라 재미 없을 수가 없음 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ역시 아는 맛이 최고긴 '
#   '해.',),
#  ('별 생각없이 보다가 계속보게됨.\n정경호 연기가 너무 자연스러움',),
#  ('진짜 이렇게 좋은 시나리오를 억지연출이 다망침... 다음부턴 웹툰원작자가 오케이 할때까지 다시 찍어야함.. 진짜 재밌는 웹툰을 '
#   '다망쳐놓은게 화난다..',))
#
# ----------UCpCiIDf9UrfRqte55FHWlYQ----------
#
# (('사린이는 다를거예요. 착하니까 라는  대사  듣자마자  소름이 쫙 돋았네 .',),
#  ('이거 설날 때 제발 틀어줘라…',),
#  ('exid 자체가 무명시절이 워낙 길었으니... 그런 어려운 아픔을 겪어서 저런 연기가 더 잘 나오는게 아닐까 싶음 하니 연기 진짜 물 '
#   '올랐다',))
#
# ----------UCrBpV_pG2kyMMEHCMTNzjAQ----------
#
# (('방금 거울을 한번 봤는데 외계인은 확실히 존재 하는 거 같습니다',),
#  ('영화 “인터스텔라” 54번째 리뷰 감사합니다\n\n100만 축하드립니다!',),
#  ('영화 중성자별 리뷰 감사합니다',))
#
# ----------UCxlv4aOnrRTXMRSL8bVJqEw----------
#
# (('세계2차대전 참전용사들이 심장에 문제있는 고아를 구타하는 영상\n1명은 고아부모를 죽임',),
#  ('이건 니아빠가 만든 방패!\n이건 니아빠를 죽인 팔!',),
#  ('여러분 앞으로 웡을 만나면 정중히 인사해주십쇼!',))
# MUKBANG
#
# ----------UC-i2ywiuvjvpTy2zW-tXfkw----------
#
# (('저렇게 모양이 일정한 꿔바로우 첨봤네;',),
#  ('첨에 오프닝 인사하실때 빵의 산에 다 가려졌는데도 꿋꿋하게 인사하시는거 보고 빵터짐ㅋㅋㅋㅋㅋㅋㅋㅋㄱㅋㅋㅋㅋ',),
#  ('이 댓글을보신 소수의 분들은 나날이 행복하고 모든일이 잘되실겁니다❤❤❤❤',))
#
# ----------UC2fsxQr6Hcx1enORxXgKpxQ----------
#
# (('Fun fact : legends watching this video laying on the bed 😊😊🛏️🛏️😆😆',),
#  ('저 제인님 편의점 먹방은 처음봐요... 편의점 먹방에 어떻게 이런 소리가 나지? 의문이..생겨요 소리가 너무 좋아서욬ㅋㅋㅋㅋ 편의점 '
#   '먹방 다음에도 해주세요 너무 좋네요!!',),
#  ('Timestamps \n'
#   '0:26 - Hi! 👋🏼\n'
#   '0:30 - Chocolate Sign\n'
#   '0:49 - Flower Cake 🌸\n'
#   '2:24 - Orange Juice 🥤 \n'
#   '2:36 - Mousse Cake 🍋 \n'
#   '3:41 - Flower Cake And Juice 🌸\n'
#   '4:32 - Strawberry Roll Cake 🍓 \n'
#   '4:45 - Orange Juice 🍊 \n'
#   '5:03 - Strawberry Roll Cake 🍰 \n'
#   '5:17 - Strawberry Milk 🥛 \n'
#   '5:21 - Pumpkin Cake 🎃 \n'
#   '6:41 - Strawberry Milk 🍓\n'
#   '6:47 - Flower Cake 🌸\n'
#   '7:19 - Strawberry Roll Cake And Milk 🍓\n'
#   '7:56 - Outro 👋🏼',))
#
# ----------UC4PpFUrfT2Pou7OwpVF0MUQ----------
#
# (('왕크니까 왕맛있는 대왕 문어다리에 매콤한소스 싸악 발라서 먹어보았어요!\r\n'
#   '쏘영표 해물찜에 랍스터랑 가리비가 빠지면 섭하지유 🐙🦞❤\r\n'
#   '오늘도 즐겁게 시청해쥬세요 💜\n'
#   '\n'
#   'I put on spicy sauce on a giant octopus leg, which is so delicious because '
#   'it is so big, and ate it!\r\n'
#   'It would be sad if lobster and scallops are missing from Ssoyoungs seafood '
#   'boil 🐙🦞❤\r\n'
#   'Please enjoy watching it today too 💜\n'
#   '\n'
#   'Aku hari ini makan tentakel gurita raksasa yang sangat besar dengan saus '
#   'pedas manis!\r\n'
#   'Tidak lupa dengan lobster dan kerang kipas di rebusan seafood khas '
#   'Ssoyoung  🐙🦞❤\r\n'
#   'Selamat menyaksikan 💜',),
#  ('안녕하세요 여러분 만리입니다!! \r\n'
#   '쏘영언니 채널에 초대되어서 언니랑 같이 해산물을 뜯었는데 이게 꿈인지 생시인지 너무 재밌고 영광스러운 날이었어요~ ♥ \r\n'
#   '해물 맛도 직접 먹어보니 정말 기가 막히더라구요 \r\n'
#   '다음에는 진짜루 언니 집에 있는 음식 다 먹고 가겠습니다 🤣 재밌게 봐주셔서 너무 감사드립니다!',),
#  ('안녕하세요 쏘영언니 채널 시청자 여러분~~ 만리입니다~~!!😊\n'
#   '오늘 언니랑 간단하게 간식으로 라면 20개 먹어보았는데 너무 즐거웠어요 ㅎㅎㅎ\n'
#   '쏘영언니가 넘 맛있게 잘 끓여줘서 즐겁게 맛있게 행복한 시간이었씁니다 😊\n'
#   '언니 나 다음에 또 와도 되지?😁😁',))
#
# ----------UCbzI92w5vWa6mEj1dACfy6g----------
#
# (('好感動哦！台灣的滿漢大餐被稱讚好吃😋我來自台灣，希望你能來台灣玩，有很多美食等著妳🥰我是妳台灣的粉絲😂',),
#  ('SPICY CHILI KIMCHI BLACK BEAN NOODLES FRIED EGG never fail to make my belly '
#   'growling my mouth watering and myself craving',),
#  ('You are by far the Empress of Spice! I’ve never seen anyone take it so '
#   'calmly like they’re eating ice cream LOL! 😃',))
#
# ----------UCfpaSruWW3S4dibonKXENjA----------
#
# (('Getting recognized by Gordon Ramsay is awesome, meeting him in person and '
#   'being invited for a taste test of a new burger is another level of '
#   'awesomeness… ❤',),
#  ('Tzuyang is now being recognize as a food critic and not just being a '
#   'mukbanger. She gives honest opinions with the food she eats and being '
#   'recognized by gordon ramsay is a whole another level. Great respect to her '
#   'since she really love food. I really enjoyed her vids.',),
#  ('진짜 대창먹방은 대단하다.. 유튜버들 개맛있게 먹어서 따라해봤는데 한줄도 못먹겠고 너무 느끼해서 바로 라면끓임',))
#
# ----------UCoLQZ4ZClFqVPCvvjuiUSRA----------
#
# (('문복희씨 편의점먹방은 진짜 전설이다',),
#  ('언니 야외먹방이나 먹방브이로그 (특히 집에서 편하게 찍으시는거) 많이많이 보고 싶어요!! 스튜디오 먹방과 또 다른 매력... 복희님이 '
#   '쉴 새 없이 드립치면서 편하게 먹는거 너무 귀여움...ㅠㅠ',),
#  ('안녕하세용 오늘은 오랜만에 브희로그!!\n'
#   '계획은 해장먹방이었는데ㅋㅋㅋㅋ갑자기 도전먹방으로 유턴.. \n'
#   '왜 항상 도전 먹방은 준비 없이 가게 되는가 .. \U0001fae0\n'
#   '중화가정에서 괴물짜장면 도전했는데 면발도 쫄깃탱하니 소스도 적당히 꾸덕촉촉해서 맛있더라구용!\n'
#   '탕수육이 진짜 바삭파삭 쫀득촌득 jmt…\n'
#   '탕슈육에 짜장면 돌돌 감아서 먹으니까 꿀맛이었어요 희희\n'
#   '공차로 상콤한 마무리까지 완벽쓰🥤🥤🥤\n'
#   '오늘도 잘 먹었습니당🙏🏻💕\n'
#   '\n'
#   'Hello everyone ! This is Boki🤗\n'
#   'Its been a while since I did a VLOG video\n'
#   'My plan was a hangover mukbang, but I suddenly made a U-turn to a challenge '
#   'mukbang..!\n'
#   'Why do I always go for a challenge eating show without preparation.. '
#   '\U0001fae0\n'
#   'I tried monster jajangmyeon, and the noodles were chewy and the sauce was '
#   'delicious!\n'
#   'Tangsuyuk was the best because it was crispy and chewy👍🏻\n'
#   'The combination of tangsuyuk and jajangmyeon is good!\n'
#   'Even a refreshing dessert with Gongcha was perfect🥤❤️\n'
#   'Enjoy your meal too🙏🏻',))
#
# ----------UCPKNKldggioffXPkSmjs5lQ----------
#
# (('그전에 빠르게 음식조리하고 음식에 집중해서 보게 됐는데 요즘은 브이로그같이 하는거 같은데..브이로그는 집나간햄지채널에 하면 '
#   '될꺼같아요.\n'
#   '햄지님이 인기있었던건 뭐든 뚝딱잘만들고 스피디하고 음식위주고 편안하게 먹고 진짜 집에서 편하게먹는게 좋았는데..기존에 보던 구독자님들은 '
#   '바뀐 포멧보다 기존께 좋아서 햄지님을 좋아했던거니까요 \n'
#   '변화주려는것도 이해하지만 왠지 잘 안보게 되네요',),
#  ('1:40 Mukbang \n'
#   '피드백을 보고 예전 영상을 많이 돌려 봤는데 제가 봐도 어딘가 모르게 예전이 더 맛있게 먹는 것 같다는 느낌이 들더라고요...\n'
#   '저도 처음엔 도대체 뭐가 다른 건지 찾질 못했는데 한 가지 좀 달랐던 건 예전에는 먹을 때만큼은 맛있게 아무 생각 없이 \n'
#   '먹었던 것 같은데 어느 순간부터 쩝쩝거리면 안 된다는 생각에 소리를 안 내려고 많이 생각하면서 먹었던 것 같아요.... \n'
#   '그래서 어딘가 모르게 부자연스러웠던 \n'
#   '것 같습니다.\n'
#   '오늘은 정말 소리 신경 안 쓰고 치킨만 \n'
#   '보고 맛있게 먹었어요🤣\n'
#   '앞으로는 영상 길이가 짧아지더라도 \n'
#   '요리과정이나 먹방중에 쓸데없는 장면들은 최대한 잘라내서 보시는데 불편함이 \n'
#   '없도록 해볼게요🙏\n'
#   '\n'
#   '•먹을 때 나는 소리는 TV소리 입니다.\n'
#   '•조금씩 더 고쳐서 이번 달 안으로 완성시켜볼게요!',),
#  ('Hi Hamzy. ☺ You cook well and eat well. Not an ordinary mukbanger. ☺ I also '
#   'enjoyed watching on how you prepared your foods. ☺\r\n'
#   'Lovelots from Philippines. ❤ Godbless. 😇',))
#
# ----------UCxtLc0Jqq3SKBWlIXM_OC9g----------
#
# (('이정도면 대창 동결건조 시켰다 ㄹㅇ',),
#  ('이렇게 속까지 찐덕한데 또 겉은 과자처럼 굽는 분 첨보네 진짜 좋다....',),
#  ('와 대창 진짜 미쳤다;;;\n'
#   '대창 드시는 거 보고 깜짝 놀라서 들어왔어요!!!\n'
#   '진짜 대리만족 너무 쩔어요 ㅜㅠㅜ\n'
#   '대창 먹방 많이 해주셨으면...',))
# SPORTS
#
# ----------UC4yq3FWEWqMvFNFBsV3gbKQ----------
#
# (('진짜 맑눈광 그 분인줄 ㄷㄷ 왜 연기도 잘해욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('저거를 ‘달린다’는 개념을 처음 알았어요… 저는 저거 할때마다 무서워서 밑에 계단만 보고 하는데 자신감 좀 가져볼까 ㄷ ㄷ ㄷ',),
#  ('“수치심이 없는자 vs 숱이 심히 없는자”. ver. 2 인가..',))
#
# ----------UCdTDdygpZKdDew2s1s419iw----------
#
# (('아 이거 김민재가 보면 ㅈㄴ 웃기겠다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',),
#  ('다이빙은 진짜 상상도 못했다 ㅋㅋㅋㅋㅋㅋ',),
#  ('훈련장에서 몰래 연습하다 동료들도 속으면 진짜 웃기겠다 ㅋㅋㅋㅋㅋ',))
#
# ----------UCdtRAcd3L_UpV4tMXCw63NQ----------
#
# (('가볍게 양갱먹고 퇴소한 성엽이형 개추 ㅋㅋ',),
#  ('김계란 진짜 전화받아라',),
#  ('그냥 가만히 이야기만 하다가 맛있는 양갱 먹고 잘 퇴소하신 성엽이형이면 개추 ㅋㅋ',))
#
# ----------UCoe-0EVDJnjlSoPK8ygcGwQ----------
#
# (('쿠오오오오오오오오오오오오오오오오오오오오오!!!🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥.        \n'
#   '\n'
#   '축하드려요…. 쿠로오오오오오오오오오오오오오오오오오오오오오오오오오🔥🔥🔥🔥🔥🔥🔥🔥🔥🙌🙌🙌🙌🙌🙌🙌',),
#  ('토크만 25분 지루할 거 같은데 형식적인 거 없이 그냥 리얼로 이렇게 시간 빠르게 가게 만드는 건 진짜 인정할 수밖에 없다 진짜 다르긴 '
#   '다르다',),
#  ('"선동은 한 문장으로도 가능하지만 그것을 반박하려면 수십장의 증거와 문서가 필요하다." 를 몸소 보여주신 김종국 형님 '
#   '고생하셨습니다.',))
#
# ----------UCT8DsZlac7D1_dx6d8Kh_Qw----------
#
# (('안철숩니다.\n파울로 벤투 일수도 있고 아닐수도 있습니다.',),
#  ('Jk는 편집이든 아니든 저걸 해떠있을때 다 해낸다는거 자체가 이미 잘해 ㅋㅋㅋ',),
#  ('진짜 온몸에 소름이 쫙. 이거 진짜 ㅈㄴ 아픔 걸어 다닐수가 없고 그냥 ㅈㄴ 아픔 ㅠㅠ',))
#
# ----------UCtm_QoN2SIxwCE-59shX7Qg----------
#
# (('15분만에 3골 먹히는 토트넘, 15분만에 경기장 나가는 토트넘 관중들, 손흥민 7시즌 연속 두자릿수 골(+1어시), 히샬리송의 토트넘 '
#   '이적 후 리그 첫 골, 3:0에서 3:3만드는 토트넘, 동점골 넣은지 30초만에 역전골 먹히는 토트넘, 역전 후 심판에게 달려가며 '
#   '리액션하다 햄스트링 올라온 클롭(이후 경기 종료 후에도 계속 절뚝거림) 이 모든 게 이 한 경기에서 나온 장면들.. 간만에 미친경기였다 '
#   'ㅋㅋㅋㅋㅋㅋ',),
#  ('케인 진짜 지린다..',),
#  ('작년 손흥민 선수가 득점왕을 하는데 많은 영향을 차지했던 라인 브레이킹 능력이 이번 시즌 드디어 돋보인 것 같네요. 하지만 여전히 '
#   '토트넘의 수비진은 정말... 할 말이 없습니다... 공격진의 퀄리티를 수비진이 가려버리네요... 공격이 의미가 없는 수준...\n'
#   '아무튼 손흥민 선수 EPL에서 7년 연속 두 자릿수 득점... 정말 대단하고 축하합니다!🇰🇷',))
#
# ----------UCVhUw50KohEPkjL3Ox2saag----------
#
# (('하이큐보다 더 비현실적인 설정은 김연경 선수죠\n'
#   '중학교때까지 키가 작아서 리베로, 세터하다가 갑자기 20cm 크고 고등학생 신분으로 성인 국가대표 씹어먹고 프로 데뷔하자마자 전 시즌 '
#   '꼴찌팀 우승시키고 6관왕(신인상, 득점상, 공격상, 서브상, 정규리그 mvp, 챔피언결정전 mvp)!\n'
#   '3번의 무릎 수술, 흥국생명과의 소송, 배협의 열악한 지원 등 많은 고난이 있었지만 그걸 이겨내고 매시즌 트로피와 상을 받고 메달 따지 '
#   '못했는데도 런던올림픽 mvp  & 득점 세계신기록 보유! \n'
#   '클럽 경기에서 최고의 대회라고 뽑히는 유럽 챔피언스리그에서도 MVP & 동양인 최초로 유럽팀 주장까지!',),
#  ('누가봐도 알리 연경언니한테 한국어 배웠음.. 인중때려버린다라니... ㅠㅠㅋㅋㅋㅋㅋㅋ',),
#  ('와씨 연봉 그거밖에 안될까? 잘생각해봐 하는데 진심 심쿵 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 언니 너무 본새나 너무 멋있어',))
#
# ----------UCYJDUekoQz0-bo8al1diLWQ----------
#
# (('축하해요 챔피언~🏆 \n앞으로 전문적인 노하우로\n선한 영향력 부탁드립니다.\n🐴 🤴 👍',),
#  ('마지막에 긴장한것보니 인간미가 너무 넘친다 형..',),
#  ('몸 좋은 애들이 다 가리고 물쥐한테 나시 입힌거 존나 웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',))
